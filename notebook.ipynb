# %%
import pandas as pd
import joblib

# %%
interaction_df = pd.read_csv("data/user_item_interactions.csv")
interaction_df.head()
# Out:
#    item_id                               user_id   timestamp  click  purchase
# 0     6198  36c0daa2-5aad-4b0c-81e3-8d276b223573  1633082142      1         0
# 1      190  c9a9b40a-90ce-42c7-8b02-1301ad4914b1  1630125341      1         0
# 2     7330  83969882-083c-4150-b9eb-19bb3197720d  1630143229      1         0
# 3     8978  83969882-083c-4150-b9eb-19bb3197720d  1630143685      1         0
# 4     9263  83969882-083c-4150-b9eb-19bb3197720d  1630143781      1         0

# %%
interaction = interaction_df.copy()
interaction['purchase'] = interaction['purchase'].apply(lambda x: 2 if x==1 else 0)
interaction['rating'] = interaction['purchase'] + interaction['click']
interaction.head()
# Out:
#    item_id                               user_id   timestamp  click  purchase  \
# 0     6198  36c0daa2-5aad-4b0c-81e3-8d276b223573  1633082142      1         0
# 1      190  c9a9b40a-90ce-42c7-8b02-1301ad4914b1  1630125341      1         0
# 2     7330  83969882-083c-4150-b9eb-19bb3197720d  1630143229      1         0
# 3     8978  83969882-083c-4150-b9eb-19bb3197720d  1630143685      1         0
# 4     9263  83969882-083c-4150-b9eb-19bb3197720d  1630143781      1         0
#
#    rating
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
dataset = pd.DataFrame()
dataset['user'] = interaction['user_id']
dataset['item'] = interaction['item_id']
dataset['rating'] = interaction['rating']
dataset['timestamp'] = interaction['timestamp']
dataset.head()
# Out:
#                                    user  item  rating   timestamp
# 0  36c0daa2-5aad-4b0c-81e3-8d276b223573  6198       1  1633082142
# 1  c9a9b40a-90ce-42c7-8b02-1301ad4914b1   190       1  1630125341
# 2  83969882-083c-4150-b9eb-19bb3197720d  7330       1  1630143229
# 3  83969882-083c-4150-b9eb-19bb3197720d  8978       1  1630143685
# 4  83969882-083c-4150-b9eb-19bb3197720d  9263       1  1630143781

# %%
dataset.to_csv('data/user_item_interactions.csv', index=False)

# %% [markdown]
# ### N-Recommended Products

# %%
from surprise import KNNBaseline
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
import os
from surprise.model_selection import train_test_split
from surprise.model_selection import KFold
from surprise import SVD


reader = Reader(rating_scale=(1, 2))
data = Dataset.load_from_df(df=dataset[['user', 'item', 'rating']], reader=reader)

kf = KFold(n_splits=10)

svd = SVD()

for trainset, testset in kf.split(data):
    svd.fit(trainset)
    predictions = svd.test(testset)
    accuracy.rmse(predictions, verbose=True)
# Out:
# RMSE: 0.1778
# RMSE: 0.1777
# RMSE: 0.1766
# RMSE: 0.1765
# RMSE: 0.1755
# RMSE: 0.1748
# RMSE: 0.1760
# RMSE: 0.1757
# RMSE: 0.1765
# RMSE: 0.1796

# %%
from collections import defaultdict
import json
def get_top_n(predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions.
    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.
    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    """

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

top_n = get_top_n(predictions, n=10)
result = {}
for uid, user_ratings in top_n.items():
    result[uid] = [iid for (iid, _) in user_ratings]
with open("result.json", "w") as f:
    f.write(json.dumps(result))

# %%
joblib.dump(svd,'svd.joblib')
# Out:
# ['svd.joblib']

# %% [markdown]
# ### K-Similar Items

# %%
trainset = data.build_full_trainset()
sim_options = {'name': 'pearson_baseline', 'user_based': False}
knn = KNNBaseline(sim_options=sim_options)
knn.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
testset = trainset.build_testset()
predictions = knn.test(testset)
accuracy.rmse(predictions, verbose=True)
# Out:
# RMSE: 0.0465
# 0.046461337102403036

# %%
knn.get_neighbors(456, k=10)
# Out:
# [689, 735, 67, 3104, 365, 688, 2414, 3107, 6947, 1202]

# %%
joblib.dump(knn, 'knn.joblib')
# Out:
# ['knn.joblib']

# %%
model = joblib.load('knn.joblib')
model.get_neighbors(456, k=10)
# Out:
# [689, 735, 67, 3104, 365, 688, 2414, 3107, 6947, 1202]

# %% [markdown]
# ### Popular Recommended Products

# %%
popular_items = dataset.groupby(['item']).size().reset_index()
popular_items['count'] = popular_items[0]
popular_items.sort_values(by='count', ascending=False).head(10)
# popular_items[0]
# Out:
#         item     0  count
# 2511    2719  3409   3409
# 3188    3589  3081   3081
# 7610    8978  2867   2867
# 2845    3082  2612   2612
# 1451    1547  2075   2075
# 2509    2717  1842   1842
# 10290  13400  1569   1569
# 1188    1264  1489   1489
# 717      761  1467   1467
# 176      189  1458   1458

# %%
dataset[(dataset['item'] == 2719)]
# Out:
#                                         user  item  rating   timestamp
# 581     689e1169-d896-4523-8a97-c70649763e67  2719       1  1629074397
# 583     d7d13b02-7da2-475c-ba5b-698833c87ef9  2719       1  1629100051
# 642     689e1169-d896-4523-8a97-c70649763e67  2719       1  1629419326
# 1233    ef5a9bc2-fbcb-4466-a887-70dce4e7cf85  2719       1  1631925066
# 1295    11e464cf-31c0-4968-ae4d-188ee0aa8664  2719       1  1632423279
# ...                                      ...   ...     ...         ...
# 529308  3c4d0011-f473-44fa-9b65-e9118a51a955  2719       2  1624616329
# 539090  b5633cde-5f00-4e47-a1c4-01d2b4c56aff  2719       2  1635050924
# 550641  25670cd5-c9bf-4ec1-b532-eecdd293b812  2719       2  1635659599
# 551352  29396054-3374-471f-b4cd-b793750e5d41  2719       2  1636366687
# 555696  f952cb46-31ee-49ff-a6a5-92254aa08663  2719       2  1639470140
#
# [3409 rows x 4 columns]

# %% [markdown]
# ### Recommendation using Implict

# %%
import pandas as pd
import scipy.sparse as sparse
import numpy as np
import random
import implicit
from sklearn.preprocessing import MinMaxScaler

# %%
dataset_df = dataset.copy()
dataset_df.rename(columns={'rating':'event_strength'}, inplace=True)

# %%
dataset_transformed = dataset_df.copy()
dataset_transformed['user'] = dataset_transformed['user'].astype("category")
dataset_transformed['user_id'] = dataset_transformed['user'].cat.codes

sparse_item_user = sparse.csr_matrix((dataset_transformed['event_strength'].astype(float), (dataset_transformed['item'], dataset_transformed['user_id'])))
sparse_user_item = sparse.csr_matrix((dataset_transformed['event_strength'].astype(float), (dataset_transformed['user_id'], dataset_transformed['item'])))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
from implicit.evaluation import precision_at_k, train_test_split

train, test = train_test_split(data)

# %%
model = implicit.als.AlternatingLeastSquares(factors=20, regularization=0.1, iterations=50)
alpha = 15
data = (sparse_item_user * alpha).astype('double')
model.fit(data)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
dataset_transformed.head()
# Out:
#                                    user  item  event_strength   timestamp  \
# 0  36c0daa2-5aad-4b0c-81e3-8d276b223573  6198               1  1633082142
# 1  c9a9b40a-90ce-42c7-8b02-1301ad4914b1   190               1  1630125341
# 2  83969882-083c-4150-b9eb-19bb3197720d  7330               1  1630143229
# 3  83969882-083c-4150-b9eb-19bb3197720d  8978               1  1630143685
# 4  83969882-083c-4150-b9eb-19bb3197720d  9263               1  1630143781
#
#    user_id
# 0     4919
# 1    18023
# 2    11813
# 3    11813
# 4    11813

# %% [markdown]
# #### Similar Items

# %%
item_id = 2719
n_similar = 10

user_vecs = model.user_factors
item_vecs = model.item_factors

item_norms = np.sqrt((item_vecs * item_vecs).sum(axis=1))

scores = item_vecs.dot(item_vecs[item_id]) / item_norms
top_idx = np.argpartition(scores, -n_similar)[-n_similar:]
similar = sorted(zip(top_idx, scores[top_idx] / item_norms[item_id]), key=lambda x: -x[1])

for item in similar:
    idx, score = item
    print(idx, score)
# Out:
# 2719 0.9999998
# 9098 0.87973684
# 8698 0.86409724
# 3157 0.84976643
# 22466 0.8447018
# 5720 0.8286689
# 15838 0.8267566
# 3330 0.8106081
# 15689 0.8054549
# 19101 0.7959048

# %%
def recommend(user_id, sparse_user_item, user_vecs, item_vecs, num_contents=10):
    user_interactions = sparse_user_item[user_id,:].toarray()
    user_interactions = user_interactions.reshape(-1) + 1
    user_interactions[user_interactions > 1] = 0
    rec_vector = user_vecs[user_id,:].dot(item_vecs.T).toarray()
    min_max = MinMaxScaler()
    rec_vector_scaled = min_max.fit_transform(rec_vector.reshape(-1,1))[:,0]
    recommend_vector = user_interactions * rec_vector_scaled
    content_idx = np.argsort(recommend_vector)[::-1][:num_contents]
    
    items = []
    scores = []
    
    for idx in content_idx:
        items.append(idx)
        scores.append(recommend_vector[idx])

    recommendations = pd.DataFrame({'item': items, 'score': scores})

    return recommendations

user_vecs = sparse.csr_matrix(model.user_factors)
item_vecs = sparse.csr_matrix(model.item_factors)

user_id = 18023

recommendations = recommend(user_id, sparse_item_user, user_vecs, item_vecs)

print(recommendations)
# Out:
#     item     score
# 0  16534  1.000000
# 1   7116  0.959908
# 2    169  0.950384
# 3  21447  0.928597
# 4  22323  0.910530
# 5    325  0.898174
# 6   6341  0.897446
# 7  14359  0.894313
# 8  15797  0.890978
# 9  21660  0.876455

# %% [markdown]
# ### LightFm Modeling

# %%
lf_dataset_df = dataset_df.copy()
new_products = pd.read_csv('data/catalogue.csv')
new_products_df = new_products.copy()
new_products_df.head()
# Out:
#       id                                           title  \
# 0  14521                                    Oxy 10, 10gm
# 1  12352           Make-Up Studio Brush Cleanser(Ph0900)
# 2  11507  Buddsbuddy Silicone Orthodontic Pacifier (1pc)
# 3  12401                    Make-Up Studio Cream Blusher
# 4  14408                    Set Wet Hair Gel Cool- 50 Ml
#
#                                       description  availability condition  \
# 0                                    Oxy 10, 10gm  out of stock       new
# 1           Make-Up Studio Brush Cleanser(Ph0900)      in stock       new
# 2  Buddsbuddy Silicone Orthodontic Pacifier (1pc)      in stock       new
# 3                           Colour-Rebellious Red      in stock       new
# 4                    Set Wet Hair Gel Cool- 50 Ml      in stock       new
#
#          price   sale_price  \
# 0   318.00 NPR   286.20 NPR
# 1  1785.00 NPR  1785.00 NPR
# 2   199.00 NPR   169.15 NPR
# 3  2200.00 NPR  2200.00 NPR
# 4   104.00 NPR   104.00 NPR
#
#                                                 link           brand  \
# 0  https://jeevee.com/products?value=14521&type=d...             OXY
# 1  https://jeevee.com/products?value=12352&type=d...  MAKE-UP STUDIO
# 2  https://jeevee.com/products?value=11507&type=d...      BUDDSBUDDY
# 3  https://jeevee.com/products?value=12401&type=d...  MAKE-UP STUDIO
# 4  https://jeevee.com/products?value=14408&type=d...         SET WET
#
#                                           image_link
# 0  https://jeeveedev.s3.us-east-2.amazonaws.com/w...
# 1  https://jeeveedev.s3.us-east-2.amazonaws.com/w...
# 2  https://jeeveedev.s3.us-east-2.amazonaws.com/w...
# 3  https://jeeveedev.s3.us-east-2.amazonaws.com/w...
# 4  https://jeeveedev.s3.us-east-2.amazonaws.com/w...

# %%
new_products_df.rename(columns={"id":"item_id"}, inplace=True)
new_products_df = new_products_df[['item_id', 'title', 'price','brand']]
new_products_df['price'] = new_products_df['price'].str.replace(" NPR", '')
new_products_df['price'] = new_products_df['price'].str.strip()
new_products_df['price'] = new_products_df['price'].astype(float)
# new_products_df['price'] = new_products_df['price'].astype(int)
new_products_df.head()
# Out:
#    item_id                                           title   price  \
# 0    14521                                    Oxy 10, 10gm   318.0
# 1    12352           Make-Up Studio Brush Cleanser(Ph0900)  1785.0
# 2    11507  Buddsbuddy Silicone Orthodontic Pacifier (1pc)   199.0
# 3    12401                    Make-Up Studio Cream Blusher  2200.0
# 4    14408                    Set Wet Hair Gel Cool- 50 Ml   104.0
#
#             brand
# 0             OXY
# 1  MAKE-UP STUDIO
# 2      BUDDSBUDDY
# 3  MAKE-UP STUDIO
# 4         SET WET

# %%
new_products_df[(new_products_df['item_id'] == 14534)]
# Out:
# Empty DataFrame
# Columns: [item_id, title, price, brand]
# Index: []

# %%
items = new_products_df.copy()
users = pd.read_csv('data/users.csv')

users_df = users.copy()
items_df = items.copy()


users_df.dropna(inplace=True)
items_df.dropna(inplace=True)

# items_df = items_df.append({'item_id':14534, "brand":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':8467, "brand":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':14780, "brand":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':14781, "brand":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':14793, "brand":"SKIN CARE", "price":3034}, ignore_index=True)

# items_df = items_df.append({'item_id':6198, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':190, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':14313, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':13480, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':9365, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':10618, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':10605, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':2772, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df = items_df.append({'item_id':14364, "category":"SKIN CARE", "price":3034}, ignore_index=True)
# items_df['item_id'].append(9263)
# items_df['category'].append("SKIN CARE")
# items_df['price'].append(3043)

# 
# items_df['item_id'].append(6198)
# items_df['category'].append("SKIN CARE")
# items_df['price'].append(3043)

# items_df['item_id'].append(190)
# items_df['category'].append("SKIN CARE")
# items_df['price'].append(3043)


dataset_df[(dataset_df['item'] == 14534)]

# items_df[(items_df['item_id'] == 12356)]
# Out:
#                                         user   item  event_strength  \
# 39      1fa52161-8421-411f-9f18-6df6eeb31a40  14534               1
# 16514   292d9b11-f606-4587-bb86-0d75a25b4a7a  14534               1
# 47768   baaa2d0b-2b42-4a36-b003-3464b9e89ad4  14534               1
# 49205   792a6084-acee-430f-b40d-81254107ca6f  14534               1
# 49252   792a6084-acee-430f-b40d-81254107ca6f  14534               1
# 106707  7823865d-abe5-4644-ac40-07192fde9cd6  14534               1
# 106924  7823865d-abe5-4644-ac40-07192fde9cd6  14534               1
# 110312  543f2a07-6853-4ffc-8bfd-a5c590c5decc  14534               1
# 139236  9df6c9a3-c48c-41b5-aa85-f5ea8f021242  14534               1
# 275322  04ce8a07-54af-4ffe-98c4-cda8de2f22f6  14534               1
# 318391  3ec45f0c-6b9b-49d3-9363-165685b6530a  14534               1
# 384515  96b4ffe6-54ff-4ca2-904f-518b376083b1  14534               1
# 397938  8b1160fa-2bcb-46da-8669-5a562cf370a8  14534               1
#
#          timestamp
# 39      1630388273
# 16514   1631168632
# 47768   1633912402
# 49205   1630524125
# 49252   1630610737
# 106707  1630389679
# 106924  1631317301
# 110312  1630618940
# 139236  1633205519
# 275322  1630361888
# 318391  1633821726
# 384515  1630364657
# 397938  1632774069

# %%
b = items_df['item_id'].sort_values().values
a = sorted(dataset_df['item'].unique())
data = list(set(a) - set(b))
for value in data:
    lf_dataset_df.drop(lf_dataset_df.index[lf_dataset_df['item'] == value], inplace = True)

# %%
from lightfm.data import Dataset

dataset = Dataset()
dataset.fit(users_df['id'].values, items_df['item_id'].values)

# %%
num_users, num_items = dataset.interactions_shape()
print('Num users: {}, num_items {}.'.format(num_users, num_items))
# Out:
# Num users: 47277, num_items 6640.

# %%
notYetIncluded = lf_dataset_df[~lf_dataset_df["user"].astype(str).isin(users_df["id"].astype(str))]

for index, row in notYetIncluded.iterrows():
    lf_dataset_df.drop(lf_dataset_df.index[lf_dataset_df['item'] == row['item']], inplace = True)

# %%
lf_dataset_df.to_csv('data/refined_user_item_interactions.csv', index=False)

# %%
interactions, weights = dataset.build_interactions((row['user'], row['item'], row['event_strength']) for index, row in lf_dataset_df.iterrows())

# %%
items_df
# Out:
#        item_id                                           title   price  \
# 0        14521                                    Oxy 10, 10gm   318.0
# 1        12352           Make-Up Studio Brush Cleanser(Ph0900)  1785.0
# 2        11507  Buddsbuddy Silicone Orthodontic Pacifier (1pc)   199.0
# 3        12401                    Make-Up Studio Cream Blusher  2200.0
# 4        14408                    Set Wet Hair Gel Cool- 50 Ml   104.0
# ...        ...                                             ...     ...
# 14750    14534                                             NaN  3034.0
# 14751     8467                                             NaN  3034.0
# 14752    14780                                             NaN  3034.0
# 14753    14781                                             NaN  3034.0
# 14754    14793                                             NaN  3034.0
#
#                 brand
# 0                 OXY
# 1      MAKE-UP STUDIO
# 2          BUDDSBUDDY
# 3      MAKE-UP STUDIO
# 4             SET WET
# ...               ...
# 14750       SKIN CARE
# 14751       SKIN CARE
# 14752       SKIN CARE
# 14753       SKIN CARE
# 14754       SKIN CARE
#
# [14755 rows x 4 columns]

# %%
items_df['brand'] = items_df['brand'].astype('category')
items_df['brand'] = items_df['brand'].cat.codes
items_features = [(row['price'], row['brand']) for index, row in items_df.iterrows()]
items_df.head()
# Out:
#    item_id                                           title   price  brand
# 0    14521                                    Oxy 10, 10gm   318.0    321
# 1    12352           Make-Up Studio Brush Cleanser(Ph0900)  1785.0    264
# 2    11507  Buddsbuddy Silicone Orthodontic Pacifier (1pc)   199.0     57
# 3    12401                    Make-Up Studio Cream Blusher  2200.0    264
# 4    14408                    Set Wet Hair Gel Cool- 50 Ml   104.0    381

# %%
items_df.to_csv("data/processed_products.csv", index=False)

# %%
users_df.head()
# Out:
#                                      id  gender date_of_birth
# 0  179db347-97e2-4e93-97c8-e0dba4dc69ae    MALE    1983-08-03
# 2  d023a4f1-5b6b-4d5d-9f7a-5d7b9a4d06d4    MALE    1982-12-20
# 3  f157ba08-cc44-4bb7-b35e-6ab1bfd19944    MALE    1991-05-30
# 5  802cff98-87be-4a92-bc4e-9064241b1707    MALE    1995-07-20
# 6  25a3bca3-d978-4962-8a24-da295535b2aa  FEMALE    2006-01-01

# %%
from datetime import datetime, date
def calculate_age(born):
    born = datetime.strptime(born, "%Y-%m-%d").date()
    today = date.today()
    return today.year - born.year - ((today.month, 
                                      today.day) < (born.month, 
                                                    born.day))

users_df['date_of_birth'] = users_df['date_of_birth'].astype('str')
users_df['age'] = users_df['date_of_birth'].apply(calculate_age)
users_df['gender'] = users_df['gender'].astype('category')
users_df['gender'] = users_df['gender'].cat.codes
user_features =  [(row['age'], row['gender']) for index, row in users_df.iterrows()]

# %%
users_df.to_csv("v1/data/users.csv", index=False)

# %%
dataset.fit(users_df['id'].values, items_df['item_id'].values, item_features=items_features,user_features=user_features)

# %%
interactions, weights = dataset.build_interactions((row['user'], row['item'], row['event_strength']) for index, row in lf_dataset_df.iterrows())

# %%
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import precision_at_k
from lightfm.evaluation import auc_score

train, test = random_train_test_split(interactions)

# %%
from lightfm import LightFM

lightfm_model = LightFM(learning_rate=0.05, loss='warp')
lightfm_model.fit(interactions, epochs=10)

# %%
lightfm_model.item_biases *= 0.0

# %%
def get_similar_product(model, item_id):
    # Define similarity as the cosine of the angle
    # between the tag latent vectors
    
    # Normalize the vectors to unit length
    tag_embeddings = (model.item_embeddings.T
                      / np.linalg.norm(model.item_embeddings, axis=1)).T
    
    query_embedding = tag_embeddings[item_id]
    similarity = np.dot(tag_embeddings, query_embedding)
    most_similar = np.argsort(-similarity)[1:10]
    
    return most_similar

print(items_df[(items_df['item_id']==14408)])

similar_products = get_similar_product(lightfm_model,14408)
for product in similar_products:
    print(items_df['title'][product])
# Out:
#    item_id                         title  price  brand
# 4    14408  Set Wet Hair Gel Cool- 50 Ml  104.0    381
# Godrej Aer Pocket, Bathroom Air Fragrance - Fresh Lush Green, 10g
# Himalaya Sparkling White Toothpaste 80gm
# Schwarzkopf Palette Intensive Color Creme, 1-0 Black
# Alpine 2.5mg Tab
# Borges Extra Virgin Olive Oil - 250ml
# Astaberry Handrub Cleanser- 60 Ml
# Milton Lloyd Colour Me Femme Roll On Red- 10 Ml
# Etat Libre D'Orange Fils De Dieu Edp 100ml
# Kellogg'S Muesli No Added Sugar 1 Kg

# %%
from scipy.sparse import csr_matrix
n_users = 1
n_user_features = 2

row = np.array([0, 0])
col = np.array([0, 1])
data = np.array([22, 0])
usr_feat = csr_matrix((data, (row, col)), shape=(n_users, n_user_features))
usr_feat

scores = lightfm_model.predict(0, np.arange(12000))
len(np.argsort(-scores))
# Out:
# 12000

# %%
scores = lightfm_model.predict(20000, np.arange(10))
items = np.argsort(-scores)
for item in items:
    print(items_df['title'][item])
# Out:
# Make-Up Studio Cream Blusher
# Set Wet Hair Gel Cool- 50 Ml
# Make-Up Studio Brush Cleanser(Ph0900)
# Amayra Naturals Hemp & Rosemary Face Wash, 100ml
# Make-Up Studio Eye Collection
# Earth Rhythm Neem Comb
# Oxy 10, 10gm
# Maange 10 Pcs Professional Makeup Brushes With Bag
# The Moms Co. Natural Clay Deep Purifying Face Kit
# Buddsbuddy Silicone Orthodontic Pacifier (1pc)

# %%
train_precision = precision_at_k(lightfm_model, train, k=10).mean()
test_precision = precision_at_k(lightfm_model, test, k=10).mean()

train_auc = auc_score(lightfm_model, train).mean()
test_auc = auc_score(lightfm_model, test).mean()

# %%
print('Precision: train %.2f, test %.2f.' % (train_precision, test_precision))
print('AUC: train %.2f, test %.2f.' % (train_auc, test_auc))
# Out:
# Precision: train 0.06, test 0.04.
# AUC: train 0.96, test 0.96.

# %%
user_mapping = dataset.mapping()[0]
item_mapping = dataset.mapping()[2]
user_mapping
# item_mapping
# Out:
# {'179db347-97e2-4e93-97c8-e0dba4dc69ae': 0,
#  'd023a4f1-5b6b-4d5d-9f7a-5d7b9a4d06d4': 1,
#  'f157ba08-cc44-4bb7-b35e-6ab1bfd19944': 2,
#  '802cff98-87be-4a92-bc4e-9064241b1707': 3,
#  '25a3bca3-d978-4962-8a24-da295535b2aa': 4,
#  '19f8d1fa-d843-4c88-b2a8-a716f9d9d496': 5,
#  '36373e4f-ceb2-4290-853f-8dbba3442184': 6,
#  'b47054e3-67fd-40af-a030-5ea64414fbc6': 7,
#  '573f83fc-0545-4bfd-9376-6fb74d6027d9': 8,
#  '1fa812f4-5875-40b6-8c01-e13dc5d53828': 9,
#  '2398db0c-61d0-4d4b-9f67-94467ed07164': 10,
#  '3b6ea257-e6a4-4bd0-8643-30296eb5649e': 11,
#  '42b58531-c9c6-4aa2-87ed-53debc6dfdbb': 12,
#  '3ad5ef61-8563-4133-b5db-9e03f80a666e': 13,
#  '632fe0bd-616d-4713-b735-e40bbbda4dc1': 14,
#  '966bf6ff-88bf-491e-9c51-4c356f32747c': 15,
#  '201a2330-2a2b-4f86-a0f9-30d4b28a4edb': 16,
#  '37993137-a751-4653-b7d0-df89f4c437b8': 17,
#  '8f96e1b5-b2ff-4d3c-9aac-6b94aad21ce0': 18,
#  'c35be5d9-0fea-4b9d-84c3-6ffb3e7d7ffa': 19,
#  'e1175834-152f-4ef7-ad6c-2a809c8845aa': 20,
#  '331e34ff-16a3-4eae-b5c9-99838fc414f1': 21,
#  '8716ba7b-d723-492f-bb3e-dcb71062bc7e': 22,
#  '4eb792a6-87b7-4af1-9837-f0304da71b05': 23,
#  'e8891fbb-74cb-4a7f-a687-5cd75681a996': 24,
#  'f6860f9e-38ed-4654-ab27-d7500124310f': 25,
#  'cfff1d24-6d68-4409-b607-7f1fe6c464ad': 26,
#  '0f22ec5d-1bc4-458b-a84d-8ad83e7ed1bd': 27,
#  '661c6190-d4d7-43fa-8e1a-8f8eb78d297d': 28,
#  '46b99887-5730-43fe-872f-cb8257e5f77f': 29,
#  '3ff7a858-f5c6-4f48-a28f-e283aae24df7': 30,
#  'd0251b19-df77-4470-b589-14c1d6a99609': 31,
#  '4123021f-b990-4497-8283-d51a7e38f364': 32,
#  '0e3817fc-7488-47ee-92f5-233ca1c4e80a': 33,
#  '2022c13b-a51a-4d2f-97fd-5430c14afdf4': 34,
#  '59d2a7db-09ca-47e0-ab34-321e567c7b58': 35,
#  'd2353e23-d47f-4b07-93e8-4d59639c926f': 36,
#  'acfe6105-c4c4-42c3-a4e3-a3c22f368df1': 37,
#  '8a1b6648-818e-4d84-b372-ff86008c06e3': 38,
#  '17184827-8b52-410e-8507-4389b2b77df0': 39,
#  '00ba2de8-c742-40be-88fa-9e333668ef65': 40,
#  'fd9aab21-a7b8-4c2f-a11c-4fa310549787': 41,
#  '44932db3-75d6-49c1-aef9-22d8db2c9921': 42,
#  '84428eab-0cde-493a-ae97-fccba13f8249': 43,
#  '907ab09c-1306-4b87-b1fc-54d69fa9b484': 44,
#  '5ff1d754-d3ad-40f9-aec3-7b5ee06b9d4b': 45,
#  '896c7eb2-fa15-48be-a8fa-628ae4476dd4': 46,
#  '66d54169-9d16-4f06-be63-7097d6bee4ed': 47,
#  '7f87bcb1-1320-4da0-bf58-3267664d0701': 48,
#  'da184974-ab03-4ce7-a980-f3be9b206314': 49,
#  '81585ea3-f80d-4308-b4ec-78d2a4649e5b': 50,
#  '5654a24e-38a7-4568-ada0-5bd067701e3a': 51,
#  'a2b9e8c0-0a38-43b0-aa14-a5ad55931a20': 52,
#  'f35d82e8-de14-473a-b7e2-112f62c9b02b': 53,
#  '88264901-5326-4a72-84a6-b03a6a8e8e1b': 54,
#  'fa3d31c4-8ef4-45b8-b8ba-c3bfaea97891': 55,
#  '22f557f7-8227-4558-8ad7-f77d8313eeaa': 56,
#  'a9f4af19-9118-428c-844e-e71882f3a9f9': 57,
#  '556d83d9-42a8-4325-8e37-badf70a83c6a': 58,
#  '8e9b0ee0-eb25-4af5-a732-7f9501eb0736': 59,
#  'f04e8cfa-8b05-49fa-9855-e6adb05b19da': 60,
#  '77ed4d67-60cd-4720-8f97-685b9c9182b4': 61,
#  'adf71cd6-3a34-49b9-b7f7-e05494fdea92': 62,
#  '2a0f9653-1480-4067-aafb-ab8234ad37c3': 63,
#  '4927703e-89c3-4cb9-8d65-871c243b0209': 64,
#  '63cb2d32-b82d-4f6b-afc7-a77858121280': 65,
#  '47900d3d-100b-4371-a6a2-b3bb8cf39b55': 66,
#  'dc6ac11a-bdbc-475e-b35c-07ce4822de16': 67,
#  'ae73466a-332a-456f-af63-559465aa226d': 68,
#  'c5ac9e7e-743b-4fef-96de-82ea0ce2dd0b': 69,
#  '955eecc6-2818-4fc4-863c-a4ee6d85eaae': 70,
#  'd24153a1-63f7-409e-b93d-fd1b4f284edc': 71,
#  'db4145f0-343c-4550-9ddb-4b42ba7b6d92': 72,
#  'c81b14ca-9cb6-4d4f-a13d-8ed08adb8aa2': 73,
#  'd73b2673-228d-4833-923f-31d94082169b': 74,
#  '4fff0374-eb9d-44d3-8fc6-216a43115a4b': 75,
#  '6356ff9d-d67b-43e3-9308-cd38cf716ef0': 76,
#  'c30cd794-9b46-4eda-87d3-85b9d67e4ee3': 77,
#  '0ed13631-7c4d-4f59-a250-3f197e4d0b8f': 78,
#  '3057a132-d2e4-4659-8a8d-b4605226336f': 79,
#  '6a6bed12-1406-4d5c-a6d6-defd88d2cb2d': 80,
#  '0af119ff-81c7-450c-b2d5-57451e5b7655': 81,
#  'c21240c6-76a8-44fb-860b-6838cb5feecb': 82,
#  'e404def9-3404-4c23-b446-f6212e0eae77': 83,
#  '57ef752c-5d76-42a3-9982-46d0aeda0abd': 84,
#  '54cb3d64-b3f2-4d18-811d-c89dabb32f47': 85,
#  'b6049431-efd7-42d7-a5c9-9e679bc4c17d': 86,
#  '970b93aa-b6f1-46ed-ba15-21ce581b6709': 87,
#  '1515dd45-945c-4aae-98c9-5ef4698ca536': 88,
#  '7ef8f652-a51d-4774-809e-dda572134e7d': 89,
#  '35bbb3cc-5765-4f3a-a1b0-12e135d59e22': 90,
#  'b238820c-2e5b-45ae-93bf-d5c076182579': 91,
#  '4e254a3a-a87b-437e-bb65-335998236adc': 92,
#  '4e6e16f5-6101-4343-b63c-9e0ef00012cf': 93,
#  'c0297730-2c85-4c01-8792-21b38349e798': 94,
#  'ff52f48c-3141-4f1c-a3e6-043c77f1be41': 95,
#  '2c1792dd-91cf-4d90-a585-e556717ac6f9': 96,
#  'c2ce0f1f-0c0b-43b4-bea3-39b64813aa3d': 97,
#  'c2dc98cd-6889-40a8-8fda-0cdebb2db28c': 98,
#  '5011734d-6472-492a-a91a-06f7dcd19862': 99,
#  'b118e145-b0ba-4b4b-8516-57fca3764951': 100,
#  '6acff9d2-e21e-4ca0-ac82-d0fca3cbdbdb': 101,
#  '3c6f1768-4ef7-461c-8c66-882505e45d78': 102,
#  '72112aa8-ca06-4ed6-ae02-25e01b150464': 103,
#  '766ec703-3091-4fd2-a062-633887a9a7a2': 104,
#  'e1a1115e-1bd1-4032-bcfa-f915e503eeb1': 105,
#  'd0401f0f-5d2d-45ac-af66-c5eee9275025': 106,
#  '206c0a09-0976-4ded-806c-47022ec0e32f': 107,
#  '8c7f0060-bec4-49fb-aa51-a97381b49c04': 108,
#  'f43257ad-bb3f-4e18-8455-44e465f56a4f': 109,
#  'e60458e9-9177-4411-8e96-69c19d3c8a64': 110,
#  '5e144097-b49c-4ba3-92fa-355a965a8822': 111,
#  '8d858efa-6ea3-4d1a-9a70-a7bc11feea26': 112,
#  '15b7d81f-f286-49b4-8de4-fa2742afda34': 113,
#  '61a9d302-033c-4ef5-8082-a1306b3c422c': 114,
#  'f4ffbf35-0281-4190-a609-14faa9b052fe': 115,
#  '09b23315-bbca-4c8d-a856-fd05e4bdd6a7': 116,
#  'dcb4d846-86ee-4f0e-b36c-3bcf41d59342': 117,
#  'a25d8519-96be-4e4e-871a-98f94499c90e': 118,
#  'b22a6096-cfd2-44b1-8090-0bc0c8fab9d7': 119,
#  '6bd72b64-9886-4be1-aea2-86dac8338c9d': 120,
#  'b6ebe62c-1d6c-48ea-8796-8402ab933bb8': 121,
#  '197717ff-8271-4029-81f1-330f63174856': 122,
#  'bbcdf3b0-519e-49be-8b8f-42432dc01661': 123,
#  '13f20f66-b225-4a1d-bc4a-ad5ee46b5ab0': 124,
#  '39a52873-ab85-4ace-94a1-9b9e6afc09f2': 125,
#  '61f0ae45-4b46-4a09-b374-f9c27b638902': 126,
#  'd678c091-e159-4a0b-a682-d8159e476c35': 127,
#  '8bb8b677-c67d-4e2d-b4b7-4262c2e24810': 128,
#  '17795d38-0eab-4c37-a14e-3267491bc645': 129,
#  '8050dd2e-a06f-4e18-b215-4fc113cc435c': 130,
#  'af1b2fb3-485f-4dbd-b0db-9a54200a43db': 131,
#  'f899a34e-8b67-40f4-a079-1f23ef84491f': 132,
#  '5e37e6d1-ab22-42e2-8285-07aa97362f27': 133,
#  'b83731fc-2e13-4a95-b464-231f0e884200': 134,
#  'e9d7ed3a-a5a5-4505-8a5b-2daf5925f18a': 135,
#  '24f41ffd-53ec-40b8-a06c-a98eff19aabf': 136,
#  'd16017e8-793a-444b-8bd8-403fb39fe2ee': 137,
#  '7d2a9d6e-843b-4b7e-9e88-31843ee3dd26': 138,
#  'bad300ef-62fc-4f74-b3d4-313760eea61e': 139,
#  '14633662-7344-4eed-9b87-027d5ded4424': 140,
#  '7b2ab010-6c3a-4fb8-a427-e59441b1e094': 141,
#  '060e10bc-efd0-4d2a-91a5-9791a3193c2a': 142,
#  '64ec7e93-1ad9-42b9-9a2b-a893d50c72dd': 143,
#  '6de73474-58a1-4e9b-961a-b872b514c892': 144,
#  '22676972-40f8-4e04-bc89-b1c67a4d1c0e': 145,
#  '376c3f42-8692-409a-bc86-36c62afd1316': 146,
#  'baa159a6-f2a9-4210-95e8-e1d932f84653': 147,
#  'fb99f57f-566f-437b-be92-141666c8a52a': 148,
#  'd4e2980f-1195-4a37-b232-0a4b9081426b': 149,
#  'ec28585b-e42e-4eb0-883f-9517ccfb12fb': 150,
#  '2e555442-f52e-42e1-b32f-c2927fb2f827': 151,
#  'cc716db2-36a8-4f68-80cd-af76c7eb35c7': 152,
#  'e95e8722-3008-4fc5-b0a1-baad57f3462f': 153,
#  'a4066294-3e28-4aa4-a59b-524fb1851ac4': 154,
#  '3ada6647-5254-4799-bfcf-6ab06702b20b': 155,
#  '6587171b-c35c-4d4b-9e7a-cc3a253bca91': 156,
#  'bf26f982-da68-4422-a7f5-9ae702715aa7': 157,
#  'd21e1a5b-8f26-4522-b9e9-8702df7571bf': 158,
#  '588210b9-0dd5-4f7e-a752-5639c5f624b2': 159,
#  '28369b67-af4e-451b-a1e3-c9568e7c0c6e': 160,
#  '39b0d625-0d92-4c91-b99a-ba06c69d8a87': 161,
#  '6c0324f2-d14b-42d5-9b0b-bc45526d2b37': 162,
#  '0bd72b40-b052-4ec2-8fa1-2b4436fdf6a1': 163,
#  '91a00302-9225-4049-8f8c-350aa6440cfb': 164,
#  'ebacb03e-6e27-4687-8943-24cc46fd184e': 165,
#  'e9d329c8-33c9-4994-afaf-ec4544725091': 166,
#  '20c146fd-8dcf-406c-86e9-5a4b11ef9e9b': 167,
#  '3877ec1e-ac89-407e-a04d-e46c33e4d560': 168,
#  '43bde32c-c4ca-4cf4-8588-95f0851d7425': 169,
#  'd9971eaa-464f-4ae0-a9d8-028a70743d36': 170,
#  '035a5c3e-6148-4a1f-ad31-33369961afbc': 171,
#  'fad91d14-5124-4b55-937e-e261938b0f71': 172,
#  '2a16e2bd-86a7-4bc6-8dc2-f315f00bc2cd': 173,
#  '48af3a54-311d-4886-aa0f-685a8978a06d': 174,
#  '27e4ef93-d853-4ad9-a755-0e45ab6b79df': 175,
#  '627eba11-a467-4d36-b5c8-16949acc97b1': 176,
#  'f95505d9-bbed-487b-9b4b-5685fcd9431f': 177,
#  'f345dbe1-f173-448f-8ae0-0790f666b16d': 178,
#  '3fb7076b-d0c5-440e-867d-043fa72c8c18': 179,
#  '6d28b46b-1e7a-4d54-8d83-8f94803d55c7': 180,
#  'c1168580-3db8-41e5-ba7b-566146db41cc': 181,
#  '4f221063-1e94-4d40-bca7-0e4cdb2cb43f': 182,
#  '973ebf2e-2214-469b-bb7b-187ccd30d0b1': 183,
#  'fe55c597-2b5b-4450-af79-5d82c241346a': 184,
#  '90019d21-f64f-455f-b94a-727015735df0': 185,
#  '6afe8ce8-35df-47f9-b1a8-a4c0189fd961': 186,
#  '39f1008f-d66d-4694-a4b6-0e26353cf523': 187,
#  '8f3daf37-5460-4734-9f4a-3788c5eb6e0f': 188,
#  'd268bff5-75f4-4539-88f1-3b2b07b27439': 189,
#  'ca1fc75b-da28-42f2-adb0-62a4f6e9fe2a': 190,
#  '63e58725-8715-4be3-af48-fe6f0bf01972': 191,
#  '4e05c0cb-d493-4fd2-af8d-cdb15580eea6': 192,
#  'c255ba79-5efd-4d23-8bb2-ce61357aa08b': 193,
#  '4ebcd52e-2e24-4dbd-93d8-069c22edc4cd': 194,
#  '3f614fd8-0b37-46c0-abd9-f957faa44371': 195,
#  'c5340a5b-7d7b-4755-8276-d5e53fd81909': 196,
#  '541ca44d-e558-4f90-9afa-b4139f25a6d0': 197,
#  'ff52c1ac-73fc-4d40-ba0b-4dd3371e791a': 198,
#  'e08a9fa3-039a-4262-bad0-e4e36218febc': 199,
#  'c7a05fd6-a4f1-4e68-a59d-2885243724ba': 200,
#  '7a82565b-8099-489e-8a24-a66cae60e047': 201,
#  '72f63297-82c1-4310-81d4-5180d2ae1267': 202,
#  '2fe1590e-6927-430f-997e-ae97e98f471f': 203,
#  '8f7fe3c8-7b18-49bb-a5d1-208cda368b3c': 204,
#  '9e25dccb-91b2-430d-a7b9-056a36a0eaa7': 205,
#  'bdc4ed11-1a4e-4a70-836f-f58e895efb6f': 206,
#  'd4384503-3792-419a-b671-a73b26c64d9f': 207,
#  '2088911b-3969-4649-8051-bd4a0a939177': 208,
#  '8f042b7c-b466-40a3-9419-1703f71091db': 209,
#  '6cea2df8-20a4-43ba-910b-4c765e1c31a4': 210,
#  '38225b89-0899-4ba0-8a33-4af6c5e53e97': 211,
#  'f75be832-88ad-423f-b354-ae6642eafaec': 212,
#  'bcd94dd0-4d80-4503-8d4a-ff41724b2e15': 213,
#  'c892e464-9fff-4299-ac09-f3d2c83414a3': 214,
#  'a15600ff-8042-4833-a73c-1cacd0482b90': 215,
#  'ffc09655-7571-4e30-aa0c-6c54dbf3128b': 216,
#  'a2aaa8ff-fb3d-45d1-8969-c6ebb23ddb96': 217,
#  'fca7d0fe-b981-400e-89d0-b2765b8e7506': 218,
#  '64653a4b-8a75-4338-a0c0-cac70dd1fca8': 219,
#  '0f7e34f1-f7d2-4ced-9bfa-338cfe17ebd8': 220,
#  '5946f7a7-5329-4b9a-a2a3-2ed49a581186': 221,
#  'd9f750ea-d533-40fb-a68a-61eb1168e39c': 222,
#  'ded89932-5233-4ab1-9fa7-8705eee3d5ba': 223,
#  'c56b3cbd-1b13-49f1-b509-fe14c558e02c': 224,
#  '1817bceb-9208-4ca0-acb4-8df6a37ba3b6': 225,
#  '4997bdec-7b7d-49ae-a800-5e5689a20972': 226,
#  '49feaf1b-df4b-4691-8dd0-4ebd01fb15e6': 227,
#  'b07fd32c-58f4-4b88-b09a-bdd2eef899c6': 228,
#  'e3f5f2d1-f3fa-4b5c-9318-9e176b4431fe': 229,
#  'ccc053d1-82a8-4965-b0a6-22302f71ef0b': 230,
#  'ca54dbf0-38a6-4207-b96f-111c694a49eb': 231,
#  'fdffabdd-b1eb-4c34-a3d2-ea42952e5f85': 232,
#  '72c33148-9914-4a13-becd-e1631738b2a6': 233,
#  '9269ef6b-484e-4a14-adf2-4b25c6f31479': 234,
#  '446bef2f-1b7f-4985-98f0-80a1cfc96277': 235,
#  'c918ee3f-aaa2-4337-af11-4873c1c427e5': 236,
#  '4c3f2616-7ffa-471b-8940-97b1bfe3ff93': 237,
#  'e7730c7e-6e22-48cf-9c3b-261c6f040d91': 238,
#  '1704154d-c444-4032-a457-6914a4eb924e': 239,
#  '6640fe78-136e-4515-b461-8ea59d8658cb': 240,
#  '2964af41-0e6d-408b-b085-3424623740a4': 241,
#  '9a52318c-3673-49bc-8b03-0522ebbb006f': 242,
#  '650f5af1-ca3c-4dc9-8d86-ef2642843985': 243,
#  'a4ea49ab-31df-49d0-b60e-3d46a71c144c': 244,
#  'cf5e0a51-1497-403a-a9f3-8562aa7da164': 245,
#  '4a2fc628-b177-4b40-a1a5-ff72a32d650c': 246,
#  '1b5fdaf7-61b2-4127-99b6-8a3551da900e': 247,
#  '85270130-f5ad-4e0f-a0e8-aba0177f743c': 248,
#  '580a72fb-aa10-442b-9c54-1e96e5d5e9df': 249,
#  'e67b924a-138d-4108-a295-7fbe721a423a': 250,
#  '7b91f65b-45e5-4db0-8443-849d2c31a9c8': 251,
#  'c022dc05-ace5-4024-a8cd-04574d37cc01': 252,
#  '11aedbaf-d9b9-4de6-a7ae-dc5d504c80c8': 253,
#  '17631e89-8145-439a-b807-46cf607157db': 254,
#  '076cf80c-06ce-4510-b581-e5c976d70873': 255,
#  '118431d3-d449-4bfa-9b7a-c4493ed662dc': 256,
#  'ab876a7a-5d42-4302-b081-77b42641d4a4': 257,
#  '2c722710-78a1-42bd-a216-7d871ccf999f': 258,
#  '52e4e92c-7924-470f-9b72-a2699c036b73': 259,
#  'e3e1b460-525f-4d3b-a30d-d431eaa7a20c': 260,
#  'd1a0fb81-6f06-41fc-bdcc-b2de2f2a5d83': 261,
#  'f27409ac-0b49-468b-bb23-47e0457f0c3d': 262,
#  '23544dd7-2b40-4128-be03-9a811df3d320': 263,
#  '5acf9cc1-635e-4cfc-9ea3-6ecdbf5c01c1': 264,
#  'b06d7611-d361-47a5-9982-6846e0e0ff05': 265,
#  '18eaa8a1-4724-463d-96f2-2185eea74577': 266,
#  '661068d5-473b-4829-b4b0-a5de1836beab': 267,
#  '1b586109-d932-4215-baff-844a2feb6ec7': 268,
#  '178953c5-ec7b-4563-ade4-65935377b14f': 269,
#  '97c6aefc-4f7a-4463-a73a-db32f1336d42': 270,
#  'a6c6cc28-d44d-496d-8a74-2fc194166ea0': 271,
#  '7d29c47e-f259-4a13-b766-5b65f0f16231': 272,
#  '504e3202-0716-47be-940a-37f0beb81bb5': 273,
#  '62b17eee-18fa-4c17-a217-bd5e0c33d78b': 274,
#  'c105995d-cced-4c3f-9e40-4391aa23bdcd': 275,
#  '6ee254e8-9153-4956-824c-720adfd07809': 276,
#  '4767fde4-fb84-4077-9f28-0c95a3c9b07b': 277,
#  'b9e82616-8f1e-43a2-b08c-3eef39d152c6': 278,
#  '9029a973-e6dc-4b86-ac5f-2366e2cd25a0': 279,
#  '167d2e5b-8a14-4ed0-b23d-2bc017e8fcc2': 280,
#  '77fad4b3-d64c-4550-8bf8-174cc247459f': 281,
#  '2133e9fc-66c7-443d-8b19-957da20c543a': 282,
#  'ded138e0-dcdf-4eee-be9e-e22741c9dca6': 283,
#  'eda61396-8ed2-4970-ae56-5697e139aaad': 284,
#  'd4a8c5e5-9576-4c85-9f5b-6478e8ba7790': 285,
#  '8471bb3a-6bce-4dfc-861e-3a411fcf29d2': 286,
#  '557448c0-9db5-4850-aa85-60c8017e2f49': 287,
#  '7d1ccb30-21a0-4cd9-9530-a4b8a1c37e8b': 288,
#  'e82c98e7-ff87-454f-8f3a-56f635b8b6b1': 289,
#  '4c6c318f-a1cb-4470-bf13-f7a32b29f0bf': 290,
#  '9ab74e44-1808-42e6-bba9-5f00a2d90beb': 291,
#  '2fe381ca-765c-48d2-ad14-4c4cfc5542d6': 292,
#  'e3980a9e-efd8-4ee1-9595-6694455c1d66': 293,
#  'dc6c7350-bacc-40ac-9f2b-48e42155732d': 294,
#  'f014482c-3510-443e-8cc2-cf600f07b552': 295,
#  '2b46faf6-3386-4787-9af8-495078af745d': 296,
#  'c282b76a-37d7-46bf-b86a-474bb04df8ce': 297,
#  '393d1a6a-fcf3-4a65-b7d0-606eaa9ea5c4': 298,
#  'f6e58371-2570-4264-b414-052e9a7f5a9b': 299,
#  '3bb0ae7c-4294-4859-aef1-29234e0336af': 300,
#  '622f6572-107c-4ab5-a834-947603b973d8': 301,
#  'adc74379-e0f2-4580-b5b2-d3989be833b4': 302,
#  '07a4869f-3b0e-42c6-956d-64a6cb4a5827': 303,
#  '77179d92-426f-49c9-8bd3-3bb62b2a149b': 304,
#  '46239028-ae0c-481a-8da0-aca92c5449c0': 305,
#  '37f98c32-2901-4552-b7a4-ae1100a3209d': 306,
#  'da3f2456-9ddc-4657-930f-4d43d9c2413c': 307,
#  '70a01896-4998-4d44-890d-c33b64b12f77': 308,
#  'd722b115-20bc-48be-9ec0-d6db59621fc0': 309,
#  '6f728ce7-ded3-4175-a9f6-d494201c891c': 310,
#  '3c52def6-c3e7-446e-bbc5-12e3a166d185': 311,
#  '56037919-f264-47ed-8ad5-c6193dfb6c83': 312,
#  'bfd30cc7-672a-49e3-8b07-eabe226c88c5': 313,
#  '5ebcd195-cc05-42da-90b8-805ce5e84b0d': 314,
#  '07a385b3-d90f-4fe4-8ada-cf5bcd378361': 315,
#  'd116b19e-c127-492e-865e-50d2afbc3de3': 316,
#  '09342847-611d-4ecd-8b66-843fc8d48b87': 317,
#  '58466bae-eb07-4f0f-aec0-6b5a19a9bbf1': 318,
#  '7a0503ec-aa1c-4e52-922e-7be36afbba6f': 319,
#  '966c834c-a978-4e54-86fc-59efe00ea6be': 320,
#  '4c1d6645-4d85-45ac-844b-4c1ed0b67b55': 321,
#  '9e1024c2-f6a9-4c07-8854-5d4042efbee7': 322,
#  'eaad0fd5-7b49-472a-b516-0b20b2fdfc78': 323,
#  '983e27f0-e8d9-429f-8b11-fb4b6ef8c13c': 324,
#  '09de64d3-97aa-4944-8adb-405b3ede2e80': 325,
#  '0d028605-088a-447f-9fb3-e4af84eac974': 326,
#  'b16e63de-b0a3-47a0-bd2d-ee633347bfae': 327,
#  'df4962cc-f11e-4f62-a4b9-22fb6523c1c7': 328,
#  '74d2b21c-0361-499d-8fac-ff9e26e34e1e': 329,
#  '15587f13-15e5-4cc1-b781-05a4de4223df': 330,
#  'c431dee1-bd34-4bdb-965f-95d9bb0df79d': 331,
#  '1522fef5-1e6d-454b-a243-8ecfb7dba301': 332,
#  '4effe93f-f02d-44ca-877c-ea7cab2fc1dd': 333,
#  '6910b34d-0163-46b1-858c-a3b39b6ae817': 334,
#  '9198147a-7edc-490d-9fa9-59ff2904e621': 335,
#  '595d1191-f15c-4a40-8ce1-b76720a6b4fe': 336,
#  '44120d48-5b7a-430e-855a-ce4a9e8aa569': 337,
#  '428732b1-47b5-4ce9-8512-21323ef591bf': 338,
#  'e6a6a344-1043-4f83-8b42-cf76c3320d94': 339,
#  '0feb98a4-6116-487b-a130-12b3f7c66f73': 340,
#  '292ad3f6-956b-4c80-b7ed-d883fca891d9': 341,
#  '550c9821-654b-49cd-bd25-82922777ab13': 342,
#  '0bcc57b1-dab9-463e-8c5f-ac80e158ca5a': 343,
#  '3cc5c0ab-7ea5-49e6-940f-01803088ca25': 344,
#  '85e505fb-9583-4acd-8341-758b7d62d410': 345,
#  'c4e5abf2-a5e9-45fa-8065-57d216321f28': 346,
#  '6584e474-0f7c-4c0a-83c5-256e9dc90ea8': 347,
#  '53349956-556d-4bf2-aaf2-5e0e0ef462f1': 348,
#  '692791db-8b45-4a5f-82c5-e58dfbe9309b': 349,
#  'e2f242e3-95a0-4bdf-9f6e-e13f5a2867f2': 350,
#  '1afb0119-6934-4882-ab1b-bf8f811b5d6c': 351,
#  '498443a3-ca35-478c-b815-de1e13cee206': 352,
#  'a2396117-3500-4217-972d-8a47bd843e61': 353,
#  'e818d3f5-a69c-4221-846c-affcd4f1b032': 354,
#  '5b854a13-b7c5-4512-a333-f615060df8a1': 355,
#  'f9eb0f0f-0f32-4151-8df2-330d17663294': 356,
#  '089637bd-d9cd-4513-9df6-9c462c714f2b': 357,
#  'b3dd4b8d-c4eb-4fb1-916e-de877c62b0b0': 358,
#  'ba86458a-1af9-4c9c-aa4b-423e44022949': 359,
#  '25a641b1-1536-435b-83b7-e970009410af': 360,
#  '526c8c91-35b4-43f0-926c-236327b7676f': 361,
#  'd69a88e3-34e5-4b38-918c-fe07b534566d': 362,
#  '154787e3-a0e3-456b-845c-ba97e68907db': 363,
#  'd74cfe08-ed6a-4b95-bc3d-94f7250c7315': 364,
#  '96fec161-6183-473b-a277-060673bf2a6a': 365,
#  '8383b315-37b3-4c82-a0b6-0d8f20ef778b': 366,
#  'a93415c4-cd3b-4893-8633-aec73719d5a4': 367,
#  '9ac1d311-95aa-42ae-bbe9-ce255b48ed1f': 368,
#  '197bc36b-7cb6-4a2d-bf50-1c6371cefe23': 369,
#  'e03ff109-499a-4bf7-89f0-20c86a338e24': 370,
#  'b70682a7-fbe8-4e4a-a836-df9e743a6100': 371,
#  'dfed916c-e3fd-403a-9200-eef2674035a4': 372,
#  'c85c3f31-60df-4b3d-b885-30350af8ad36': 373,
#  'f96dd314-3b15-4f4d-baec-e13b7b82f03e': 374,
#  'e64ef43b-0ee2-48d0-b095-373bf0ca870d': 375,
#  '2249704c-2479-44f2-81da-0fb04da54adc': 376,
#  'dc60ca54-1c50-4465-9acc-f9168f0ed8a9': 377,
#  '4a96d61c-02c5-4985-9a8d-6dda1694b4f9': 378,
#  '31c61fb5-818d-4408-b82e-72bed634a6a9': 379,
#  'fa773de7-0996-4f4d-a8b9-e850d0ffc8bf': 380,
#  '66af67ff-2510-40d6-a59d-625714cc482b': 381,
#  '02618edf-4a70-4d70-bc18-635ebc192cd0': 382,
#  'a5cc9a95-cf7d-44ad-a610-a24dcc672d53': 383,
#  '587fc299-323e-4230-bf9c-19fd74029845': 384,
#  '1047bc41-4785-4e9d-8a26-b9ecea20f591': 385,
#  '6ed963f1-848e-41b3-ad2f-159a43ae9007': 386,
#  '77132db8-0802-434b-a074-94e984fcce77': 387,
#  '537c7dbf-9ab9-46c6-965c-f38c8095e58f': 388,
#  '28d98b7f-7d09-41d2-a49b-683c52fc6678': 389,
#  'd4dea479-932a-4557-b41d-0ac965f1297b': 390,
#  'a1eab4d0-5193-45d5-a482-3a943c7fa832': 391,
#  '52162c57-2a53-4b12-9325-903544650be6': 392,
#  '72278843-10f8-4335-88d3-432b0f530b5f': 393,
#  '12aefe9e-9f58-4444-803c-516896dcd4d5': 394,
#  '69de3b8d-344d-41f6-811d-569dbe6d65ab': 395,
#  'cc26eb28-9b01-42c6-be2f-6fe052dfff4d': 396,
#  '0246fa4a-f3b6-4ba5-b71b-25f2311c97f9': 397,
#  'bf3d5d19-8620-4d0d-ba68-bd34bb529dc8': 398,
#  '75a26529-8a66-4b48-affb-ce7d94d95719': 399,
#  '16b49ba2-bf4b-470e-883b-8f4969251313': 400,
#  '58a8dbf0-f150-4004-9d5a-9ccf7f0cd5e9': 401,
#  '2f26f389-a90b-40cc-b8b7-4cfda52763fe': 402,
#  '1119cd92-b5f8-4da6-a179-9f1ff2ef0ee5': 403,
#  'dd69d38c-7161-4daa-95a1-4f2cc7e6fdd1': 404,
#  '49c50980-3587-4390-9614-3242bf38bee9': 405,
#  '3745a086-7c48-407f-a046-995475e28fea': 406,
#  '9020343a-f80b-4637-87a6-54738a59c62d': 407,
#  'f59709d4-3f0d-4ae3-82c0-4d4109635c7e': 408,
#  '7be4dfd5-083a-407f-9d19-e21caf5aea80': 409,
#  '8c701720-6488-4e89-be35-9928e595fcc8': 410,
#  '240fd63e-4d64-4f89-a013-38667ac78f69': 411,
#  'ea990767-e29d-460a-8d86-3aea017cdc2b': 412,
#  '7bfe71dc-4010-469f-846e-39bfc93943ee': 413,
#  'a94e1a5b-a423-4cd7-b7d0-c92e73c7137d': 414,
#  'a836a3f7-84bc-428a-a2ca-3dcc41b03062': 415,
#  'b96ceeaf-fb64-4551-b475-12b6f32fbcb2': 416,
#  'a59470f2-a317-4ff5-89bf-3eeed88ff8ef': 417,
#  'fecb6bf5-afe4-4b6d-82a6-d11ddef455e9': 418,
#  'bbc0d07d-bf39-4772-816c-6ce030316128': 419,
#  '3359de8d-0978-4c6d-9c50-b117770ade1a': 420,
#  'beb59e20-0b77-4bde-949f-166fecfb3108': 421,
#  'e8ca1c79-e121-4493-b778-5f36b7ceaf35': 422,
#  'e17c61c5-502e-467c-b2e7-167e7538016f': 423,
#  '1e5b8ea0-ca2d-483b-8fe2-49f6c59f6716': 424,
#  'e87919df-7855-46e2-9427-558e32faeec5': 425,
#  '8ff72d42-4617-4419-afb3-b66d6e3381d5': 426,
#  '82dbd812-d212-48b3-954e-997d980869e2': 427,
#  '6ecc3e8f-03b6-4677-b71a-e3d47ae04b6c': 428,
#  'b2018736-fa22-4637-81f0-c47a81711014': 429,
#  'd848d645-86c6-4b53-8fad-0662dba50924': 430,
#  'd16f4c6e-0e7e-464c-8017-cfc5cbb177a2': 431,
#  'd054686b-483d-4fa6-bf92-bffb13374eb9': 432,
#  '6b3ff5b5-e6ce-4265-8134-4fdc8f73e90b': 433,
#  '8e251582-2079-430b-a593-728c19b316de': 434,
#  '1e4436b8-b30c-40b6-a740-df6c312c8b70': 435,
#  '4098514a-8a03-4478-bf0d-3d000365b3ce': 436,
#  'eaa03204-8a0a-449a-a672-1bbf7e620617': 437,
#  'be99b3ac-aacb-4e9a-9d57-1d22ae325ee5': 438,
#  '5d6af03f-2317-4476-b4bb-3aa029b6f83d': 439,
#  'cf0e6641-758d-4cd7-ada6-8960e6e690b9': 440,
#  '26284e12-b964-4afe-b49b-c7bc46daf7a8': 441,
#  '390293ba-4399-46a5-b7be-094db10fa9a6': 442,
#  '9597bab5-e8f7-4aea-b030-d7aac67581cf': 443,
#  'd6e04bd3-3fdd-41c8-b71d-71ac8757caa3': 444,
#  'a01489c4-fbe2-48f6-b662-9d6b3a31df98': 445,
#  'bad0f292-17ed-44d5-a8cd-538b20f883b1': 446,
#  'd3dc7372-7bd4-455a-b9b5-aa83746f615f': 447,
#  '5a22ca4d-1229-48df-bbf1-78169f33072e': 448,
#  '37dc53ea-fc9b-4363-8ff7-7d99c4234ee7': 449,
#  '7d115e71-8173-471c-b811-d493714a56ff': 450,
#  'cedae381-a7fc-40d4-80c2-7300e25cb77a': 451,
#  '2902d26f-f826-42b4-b19a-08a152f3ddf2': 452,
#  '3bd5b43c-1bfd-4b75-a1d8-9f200489847c': 453,
#  '6589cec5-412c-4319-ba64-6588ad81cb5d': 454,
#  '50d3a900-4906-4081-a98b-4cd264dd57b0': 455,
#  'd946c91d-cbf5-4da5-9ef7-03725b60f1e6': 456,
#  'cc522856-6876-4fe9-af82-8edcbdd3e5b3': 457,
#  '4b9b4353-d02d-42cc-aea7-0e24ed842492': 458,
#  '9ee94ecf-9729-4cb9-ac26-4c0606eb5b26': 459,
#  '988c36a8-5773-47fa-9720-8c56ece20676': 460,
#  'e8328cd3-e431-4a83-bc60-f066b76363d3': 461,
#  '728f6201-cc41-420e-a39d-d4a00a2c7b7e': 462,
#  'ba3ebfa4-1c9f-40c1-b434-805548af0c0a': 463,
#  'b58fbe37-a7af-4f11-8f7f-3605920a5e26': 464,
#  '740b80a8-c9d2-46b3-b012-0451e6735586': 465,
#  '1cc8d293-8d2a-45be-9135-73d43c3ddc27': 466,
#  '8eb914f7-eb0d-4d3e-8f4a-f467070b5387': 467,
#  '92d75b9f-c40e-4a00-aeaa-038731aba91f': 468,
#  '95aa46c9-fa92-4049-a85c-d0feae73b4d3': 469,
#  'bace13c2-1201-4a42-bc86-11a40990c1a9': 470,
#  '7a1e6980-79ae-4947-bf95-c79d09faca3c': 471,
#  '3264a8b3-a942-4216-b387-c6253b710072': 472,
#  'ec7320a4-350d-41f5-bc7c-e8cb3c2c569e': 473,
#  '242a104c-c997-48f2-af2e-c492bbf1d3f0': 474,
#  '1e35c38b-6b7c-4dce-9d91-0215e893967d': 475,
#  'a90b480c-a039-413c-ad84-7d20b1543def': 476,
#  '3d33146b-9493-48b6-8869-0acfe52d7ffb': 477,
#  'a17d265d-f67d-490a-9dee-2d20cef1df73': 478,
#  'cd95d8f8-97a9-4658-8f5e-1e52a4108a24': 479,
#  'dd47ea64-281a-4699-92e8-3b53cb83620a': 480,
#  '4b34bc5f-6226-4c8b-9971-8dac81fe84e0': 481,
#  '9af16ac9-c4d1-4d56-a683-20031f610b70': 482,
#  'f14277c8-8e95-4229-81a6-36c1978a64a7': 483,
#  'c5942a73-e12b-479c-8e3a-ea0c5f8d9fc2': 484,
#  '117797ff-f4b6-4198-8392-8ac9730b08fe': 485,
#  '52249280-4e8d-41b1-a355-8347c0f31a29': 486,
#  '738c7675-03f2-49c7-9640-abc07a160ee7': 487,
#  '8f83df66-1d13-4134-8c1d-3f288e5909c9': 488,
#  '384568ce-79a2-49b6-b000-f3ddb4e4e128': 489,
#  'f5308f29-4bc1-497b-bf21-97bd93fc2f3f': 490,
#  '57a6e042-682e-4f1e-ab30-a449e8c3695f': 491,
#  '90ef42ad-0dd1-4234-8c9e-49b80765dc65': 492,
#  '24260276-b7c5-46c9-a506-b9201907a66c': 493,
#  '29c38987-3b49-4394-b20b-7f65e441ec9e': 494,
#  '1f8ae456-1f41-448a-8644-e3a0f0f8f1c6': 495,
#  'e2275c99-d01d-4bc0-8cc7-87764a416bc1': 496,
#  '46104a70-8a2e-448d-8556-7d9a19cdee78': 497,
#  '990a8451-3e70-40d0-9f97-86a7e5c9e483': 498,
#  '911cb737-8cc9-42be-af87-15e88913799e': 499,
#  '107a6092-c3a1-45fb-b997-8d1c5ad9afea': 500,
#  '23ac6a56-d980-4792-b0ed-5c463cc8ac05': 501,
#  'bad161a9-f92c-4688-abc0-225e2a005be4': 502,
#  '1c22be01-e6ac-478c-aefd-a623a976ff61': 503,
#  '4ba7e776-3c14-435b-b60c-3a13873138c4': 504,
#  '003e9d80-5dc7-447c-9876-417cdf7289e5': 505,
#  '63df9319-ccaa-4818-bde1-11a3e6b39db8': 506,
#  '3569b2df-6782-4bec-9ae1-6669b211b831': 507,
#  '07564bd3-d6f1-42dd-b848-545e58670d20': 508,
#  '1fc82459-aa03-4bbf-b3be-a26e7c5c7674': 509,
#  'd1f61190-5210-48fb-8722-b9cb82ab5af1': 510,
#  '9adc4299-7aef-4a95-90c7-9e6baea7e158': 511,
#  '30531666-e5a8-4e35-b052-900544b1deb6': 512,
#  '0c5bf258-e81e-499d-a06a-12e101e9b15c': 513,
#  'ab67e72f-fd0a-45fb-ac74-91a322bbdba2': 514,
#  '4e8ba1de-df68-43b0-bcd2-5b40b68bbfa5': 515,
#  '950311c6-4152-48c2-904c-08aec59453a2': 516,
#  '9034fc30-2ba2-4d42-a5fa-ba8521d276fc': 517,
#  '419ad093-8eac-4f5e-abe1-ee4d12ac2f10': 518,
#  '76fd1118-cd0f-456f-9fb5-353d35b1fc44': 519,
#  '83628c22-c08e-4ba0-b1cc-6ef59868bcfc': 520,
#  '94ac3d69-305c-408e-b793-7a6b2cde8d7a': 521,
#  '402bc198-5d95-41c7-bf13-c0038e34849e': 522,
#  '77f860f0-1bdc-4757-a7c6-c8a64fddada7': 523,
#  'eaa5c245-2a96-43a9-b272-632a2f6de878': 524,
#  '0f6d1b4d-cb33-499d-b2cd-2e4864985f7b': 525,
#  'fd12aaf0-14f4-4d6a-bfc7-92e2943f07fb': 526,
#  '5139a374-876e-42c0-b1a4-fbebb72a1ce4': 527,
#  '92aeb0e4-1861-4a6f-8da1-fdb4b2319f85': 528,
#  '4ec77217-0954-4020-89d3-dabf2f5fa39b': 529,
#  'f94dbc63-5b3c-4f30-88ee-36fe2dccc8dd': 530,
#  '3f7e9f3f-1873-4caf-ba99-eb5822ead995': 531,
#  '549f6c49-d284-4b19-b51e-8a9534e1ff65': 532,
#  'aed86d82-5b87-412e-949c-2e2ecc6c5d01': 533,
#  '5c28e35c-dc18-4f5b-aa57-06edf9e16a34': 534,
#  '0aaa0b43-c7dd-46c6-92d9-c93c2778672b': 535,
#  '3cb13049-c2ba-4017-9da2-4b5e31040f7a': 536,
#  '7ed9edc0-83ca-4233-b841-b5e3c5ec20f2': 537,
#  'd5f5a4cb-4f80-464d-a6d4-dd38f429d683': 538,
#  '5e947740-4924-4680-893f-d8b78cfbd9fb': 539,
#  '13dc9a1c-9a87-4e1b-afac-c6d1f6ef01e9': 540,
#  'c7d8d086-d450-45a5-b91a-6d2f3b64f1f2': 541,
#  '1f94d71c-2fe5-4ad2-b9be-e8abaa448618': 542,
#  '7271b024-7cdb-4399-b421-755ea9589bf9': 543,
#  '6c2cb1bd-1a14-4c24-936d-e5648b64ccee': 544,
#  'e40d67fa-473e-41ff-9041-16fccbc278af': 545,
#  '27e419b2-d9fb-4f51-9912-cb6cde2fabda': 546,
#  'bae9f46b-5645-4ee8-99c8-cc4e6e02b96a': 547,
#  '33fde72d-5346-4177-ad56-64836a98ee60': 548,
#  'dadc937b-c630-44c8-8d29-f3809ea7f51a': 549,
#  '051770d6-4646-481d-9299-aef2421a8a8a': 550,
#  'f78bd7bc-8f19-4e21-a4cc-ad7f31ac3185': 551,
#  'a1f84eb1-9418-439e-8cd1-466770c0e144': 552,
#  '9b044056-8081-43b6-b228-be7774cf441a': 553,
#  '227eaff0-c0c9-46a0-b52f-5867d9bea7e0': 554,
#  'a0da57ba-746e-4d5a-8732-5b8365061083': 555,
#  'e40cb7e9-c6e6-47ec-aa4b-422fddbfdeb8': 556,
#  '47135c30-c91f-4412-b8f0-724ff7e24359': 557,
#  'b76cce14-e07e-4e58-a797-4bc340ff0779': 558,
#  '1032badd-7594-4121-9d0a-e4b9c7566c47': 559,
#  '36b8f835-e6a8-4927-92cb-6fa6f839f596': 560,
#  'fc639ec9-7c9a-4703-b933-a8d8992c6b51': 561,
#  '11360bde-3d62-40f7-ace8-7241391b4d72': 562,
#  '48ddb8e2-8943-4a96-9a4f-5cbfba231a0d': 563,
#  'f190bba3-fee9-4f22-aa18-3db0343809a1': 564,
#  '913d3aa8-3fcc-4075-bd11-fe2c82d1b955': 565,
#  '3fc28e99-b4c6-4a01-b8b6-a883aaa2d8b6': 566,
#  '3a8d5c6f-a0b9-4279-812f-7fcbb992db35': 567,
#  '32895416-85f2-4a28-bb45-d66e9f9ee6c6': 568,
#  '01e651b3-aa96-46f0-9e88-e2f7d6ce4814': 569,
#  '239c1b83-9551-4063-bdc6-73b7b96f8c13': 570,
#  '210e8f36-fa62-4524-b961-c473911b49a4': 571,
#  '42de9c38-e477-403b-91d3-22d7bcf01fec': 572,
#  'd5c02e3c-d696-42f8-8866-18b83abfa2b2': 573,
#  'd6afe22b-4ebb-45a6-8969-d2575f140786': 574,
#  '283fa788-a729-4a79-a300-a1535556f66c': 575,
#  '4b082ac4-d391-4907-adc2-6f58ecd83d28': 576,
#  '6d2c70e6-574f-4377-ad52-49826a687770': 577,
#  '95946e4e-a490-415f-b74a-cbcad661d928': 578,
#  '318ddee2-9838-41d5-893c-d8e37d3bca4f': 579,
#  '579559bd-05e1-4b48-aa12-194db924bb4d': 580,
#  '537de6ff-00a4-475b-b06e-80e69942b9b8': 581,
#  '22b7093c-0138-4e13-bb1a-a8ddb2e453d5': 582,
#  '8c00067c-8f4c-4ac7-9993-ffb418a6c68e': 583,
#  '2c420754-d772-4b5e-8de6-f11f0ae60ebb': 584,
#  '0c1fc53d-dcc6-4b29-b3af-6e5d2eee3623': 585,
#  'da101a5d-e43c-46e3-b167-79d7d3337ee8': 586,
#  '4036955f-f2d8-4d63-b3cc-0fe5e15eb3c1': 587,
#  '3be30a1e-ae2e-4754-abc9-9152ac539592': 588,
#  '1d0fafe8-3318-443d-9cf6-f84312122563': 589,
#  'ed31cc5d-9f1b-4b6c-adbd-2e0a2d339bf6': 590,
#  '0e28ae93-08c6-433b-af2b-3f27809c2a93': 591,
#  '6167ed5b-70b2-48e1-bcff-c847644dd833': 592,
#  '6f84a627-8cd2-4d58-a890-c009c779b731': 593,
#  '4ef4da8d-8e34-4c71-937f-8579ff7b8f3e': 594,
#  '5fa933bf-8e99-4dd0-87a4-8f2d0327c98f': 595,
#  '67c9ec6e-a436-4853-ba1e-30773308f875': 596,
#  'b5d0df3e-e8d2-45b7-a222-69c3b9ef45b2': 597,
#  'a346dafd-9a3d-4b76-909d-02f59f738fd3': 598,
#  '4dc1938a-7ce7-44e2-8668-a6ea56b931de': 599,
#  '02b56ebb-3072-4fd1-9ece-502ea984a7db': 600,
#  '79c669b3-1530-4089-96b2-48a79a588216': 601,
#  '3de3db81-8825-411b-b62f-486234052d39': 602,
#  'a76a7a65-f084-44da-a06d-3822d582e2b1': 603,
#  '97a724fc-2733-47c1-9dfe-39bebe726104': 604,
#  '5ff810bf-0a77-4a2b-9721-1cb88a670179': 605,
#  '16bb992f-e5c1-4fd7-8bd1-e182b57e7b9a': 606,
#  'c600386c-c7d8-4017-a36f-bff15fa0b956': 607,
#  '8ca824f8-bcf3-4ca2-a54c-eb034ff03d40': 608,
#  '9ed69388-008c-42d2-a65e-cf9c60b68f2a': 609,
#  '1c7b47a2-228d-4d31-8ab8-6b4cd356e5af': 610,
#  '7ed1b5a6-b34c-42cc-9644-8e25fa7e85f2': 611,
#  '9d9410fd-45ba-4f15-9d23-21e8f9fc6eb0': 612,
#  '7f039aa6-b0bb-452a-969a-371b4e959ff9': 613,
#  '287870ba-e92c-4dae-a59e-f92a78e7cc13': 614,
#  '47da2f09-5e26-4918-8fb8-a1c18dae34c4': 615,
#  'e9e2bc80-a6e9-46af-8ada-31d9f1687e63': 616,
#  '999c5f0d-1b4d-44f1-b8c6-483682bf90c3': 617,
#  'c2434340-45ed-470a-97e3-bbb7710b5418': 618,
#  '8bfec3ae-4c0f-4e31-a057-d4b239223c2e': 619,
#  '2a0d73d9-7a3e-4ac1-b8e0-a723a3999d70': 620,
#  '71ffd126-3714-4d86-b760-fec427882770': 621,
#  '3f209c60-a7f5-4b4c-9a18-7269e4624ed3': 622,
#  'ff0c7cf9-b7fd-4fdf-a524-6a461c1147d6': 623,
#  'd32a86a6-f91b-4e40-b604-f8c55b0b29d8': 624,
#  'e78aaa67-a037-4e2c-8488-0390e5e78f16': 625,
#  'ab536083-7268-43ab-84bd-8a65eb873d49': 626,
#  '99de3972-a5f7-4bad-9790-d03becec812d': 627,
#  'cbb93bc9-c7c4-4baf-b049-31a5e2a46d25': 628,
#  '9dd4274b-0da3-47e1-812f-f1349d591f78': 629,
#  '211cfa4e-b188-46ef-b9b7-80ccbeea2e6f': 630,
#  '114c440e-2145-41e9-bc5a-91a976d2e74c': 631,
#  'a3db7a0c-451b-445f-bd9f-87ced2cb2643': 632,
#  '5d760bd4-a24a-4cd5-8b8e-0cc423480386': 633,
#  'c20d5727-ccaf-4ce4-b1b7-8b86c2488819': 634,
#  '1927f992-eb32-4ba6-9b6d-21470f35689b': 635,
#  '2dd3fb65-57d0-4af2-94f3-4bb754df4c1a': 636,
#  'eacb9b4a-f6b7-4481-b222-c914db41ecdd': 637,
#  'c3e35cea-4040-48db-88e0-ac86124c142b': 638,
#  'b3a9fbf4-dfb8-4081-8fe2-8fd0948fc4d6': 639,
#  '25ab1fcb-65c7-4637-8375-4d24c935caa4': 640,
#  '69b9ada0-8312-4fff-8748-f66ecea438f2': 641,
#  '20e5c30a-b4f5-407b-bfb7-ed4abccfd2b2': 642,
#  '0b106301-9223-42d7-8d89-b553eff63f67': 643,
#  'a865c009-21d6-4dd3-b023-d89178cd0639': 644,
#  '2e822b07-9385-4d6f-9806-3f536a4805ec': 645,
#  'f8a26b8e-9dde-42c8-811d-d855108d5c69': 646,
#  'eedceb0a-2186-4589-ae46-a6660ab50ada': 647,
#  '55cba694-5800-462a-9fb6-1d0f8e1b5d86': 648,
#  '7e0afc24-2570-417b-9b86-24ad289258c4': 649,
#  'c433bd75-0a54-4fee-bd8b-2a30d1ce3da5': 650,
#  'ae450925-fef7-4d16-af2d-7821e1f7aff0': 651,
#  '20c5d2e3-34aa-4b10-9672-ef6468f5aed5': 652,
#  '22f136b8-709b-4821-9d62-55a73bd096eb': 653,
#  '18a39c98-e1e8-47ac-b672-5f751940f5e0': 654,
#  '4e23416f-afd4-4a24-807a-6e3609b30797': 655,
#  '51fd143d-3c2b-4f8c-a24b-b2513ba50604': 656,
#  'c8ed1c1e-dfbd-4353-82e8-48d4c969f7f6': 657,
#  '6b24a586-2515-448d-bf5a-5b071c9728a6': 658,
#  'b7efa2f4-f035-49e0-831f-aa59948c121b': 659,
#  '633c920b-73a4-4a2f-b8ab-b4e8bcdc8b82': 660,
#  'b2e9ac10-37c2-4bdd-b25c-14a5e24e1b38': 661,
#  '9006c58e-9f70-41de-af58-8bac0afaf9cb': 662,
#  '1ce56ca1-f0ab-4430-b67b-4561297fac32': 663,
#  '28bf0be8-6c54-43c6-870c-dd0116915088': 664,
#  'c1c00033-ac0a-4edc-acce-8cb23915a1cf': 665,
#  'd5198742-82b2-4cad-8ce9-854339fcbf56': 666,
#  '6a563c30-5ffb-44ef-885a-a9ead6b4ffab': 667,
#  'e1f25e11-a619-436a-b2fa-feff1ae34c5b': 668,
#  '3abd889e-ac2c-4877-938b-2a9f74968d56': 669,
#  '8c651998-74eb-49c4-b087-fc25b05e1c8d': 670,
#  'eee4db9c-a2ae-4e91-94bc-adf501ebc76b': 671,
#  'b466953c-ec9d-48e8-a25b-17dcb0cde0ef': 672,
#  'b46dcfaa-4a77-4fd0-8b72-f22d0d0182ab': 673,
#  '5eace5d5-521c-4139-8e54-47b31fd69e41': 674,
#  '7485e9b1-bd70-4232-97c6-23b5a037fabc': 675,
#  'c22eadc2-1247-4378-b4ce-80509c20e875': 676,
#  'f2fc4299-63f2-469c-a8e7-978b12935618': 677,
#  '193a5fde-70b4-41e4-a21b-4c62d7904e4d': 678,
#  'af386eb4-822b-4976-a3ca-b3668ec78a3f': 679,
#  'd6ca7731-cfcc-486d-a87b-2165d94cb38d': 680,
#  'c65ad8b7-d626-4aaa-92bd-5d2866eac546': 681,
#  'f48e7b2c-80d5-441b-bbd5-98c36feacda5': 682,
#  'b6344bd9-e09f-422b-9301-27f8b3398793': 683,
#  'cb067d8d-90dd-42bb-aa57-700f5cc4f4b9': 684,
#  'af383e56-79bf-4d34-8631-e916ca61eb89': 685,
#  '9a5bc92b-407b-435c-b516-710900d5565c': 686,
#  '3b6a10b1-167b-415b-9dc5-9f698ad0ebeb': 687,
#  'cf77e897-7098-413a-9e57-c534d8dd16ab': 688,
#  'd72dcc60-0288-4d3f-9763-65de70d123e9': 689,
#  '1decd02a-52d4-4b8f-a812-d465fe512c4b': 690,
#  '39078a2b-fc55-4ddc-8136-965789309be3': 691,
#  '57ac28fb-6047-41e4-b295-d5eaa7563e6e': 692,
#  '7f9694b5-446e-4de9-9d1d-8c0a7e5f09f5': 693,
#  '7544c96b-38e4-4c55-a78e-aa58c791bdcf': 694,
#  '72bcda8d-0816-4e08-863a-68b5958311cd': 695,
#  '20ef806c-cb19-461b-ba36-a93a225d5341': 696,
#  '738a43d8-25fd-49c1-958f-43bf81a43ac3': 697,
#  '8c5e5109-54cb-4b61-9c97-7a36c7ec8d7c': 698,
#  'e23932e3-9493-4395-bf3b-aa4666ac4e65': 699,
#  'a6e30416-2bcc-493c-86af-4a9e80097e15': 700,
#  '196d852d-3dfe-4dbb-b6e3-69c2be33dcf7': 701,
#  '2bd861cf-8b87-46b9-80f8-006daadfab94': 702,
#  'ab5fb44a-661a-4cf7-a688-2875fb3951d5': 703,
#  '69509eac-ca4a-476c-835d-fcaa44b901ca': 704,
#  'a14cd5d9-f55a-46bb-90c5-501be1a53839': 705,
#  'ed480a32-374e-423c-83dd-5bc77239b3cb': 706,
#  'aa315ec6-cfc5-4ab4-969f-a1df7095dba3': 707,
#  '9d7e503b-4de9-4762-9ee0-464963acdbdf': 708,
#  'c636f295-afa7-420d-a9af-a2f0591bb64b': 709,
#  '7bab8b3e-db8e-4c07-a1a1-da3594c1f0ec': 710,
#  'a2cef0d4-f4c4-4139-8c85-db64987f98dd': 711,
#  'dfe68930-1c5f-4af7-9d6b-6510d1554832': 712,
#  'd5276b71-28be-4738-b2bb-fdab8845bceb': 713,
#  'bd739f40-6a2e-418f-bf35-d13095fd37ba': 714,
#  '50ba5296-8f15-47e3-b0fc-fb4dc84e66cc': 715,
#  'a11bfc93-4f0e-45cf-9870-303bc8a63c0b': 716,
#  'c1fb8693-9fc0-424d-9ed6-447aa18a7869': 717,
#  '4bddf6ce-85a9-443a-af4c-bbdf19b861a7': 718,
#  '4f8cc163-35e6-463e-9c2d-93ec7e75d036': 719,
#  '521e5672-c135-492d-a1ee-dc7d68e13d22': 720,
#  'b4c2531f-4321-47e1-b811-36d67cfa91ab': 721,
#  'bc08d173-115b-4bab-aa48-fa5316eb4672': 722,
#  '15482323-0e15-4d2d-91f4-4ca39e3313e1': 723,
#  'c3a395ff-3311-4e70-982e-6d5d3e34898f': 724,
#  'ac910f78-712c-43bd-a808-eabb52beeb64': 725,
#  '6edab4e3-a5cd-4d9c-9fee-a64c13ca87c2': 726,
#  '1652e14a-3d61-4fce-8547-41dc0ef9e783': 727,
#  '914aa15c-7066-40ab-9645-ed3deb065141': 728,
#  '371d5754-0e6c-4499-8b95-29bb9e9aacb6': 729,
#  'be93a614-3f12-4e54-be76-5873c449d5ac': 730,
#  '2cd0fc03-070e-4bd9-b0bb-562037f351fb': 731,
#  'abd64d11-b112-4dbc-a38f-795b8fbc6d90': 732,
#  'a41b21fa-4a0b-4887-b707-e26cf415ba57': 733,
#  '562fc4fe-12c3-4eea-aaee-5e9d1727d77e': 734,
#  '909f8d46-57e1-45eb-9fcb-10194adf902f': 735,
#  'e1145760-98bb-4dc5-af20-1d93999b21e8': 736,
#  '69cc5d96-863e-4236-a43e-e8a3228f212b': 737,
#  '4c7dfcdb-7bd9-45a5-932b-638a3f1393c5': 738,
#  '0ed33e9d-ec08-404b-8818-98fdb51c1a3e': 739,
#  '6199b1c9-f769-4bd8-8213-f4fd8d927b79': 740,
#  'e2f1f85e-7262-4b40-b45a-15898c9377db': 741,
#  'e26e362b-f39c-4337-bedf-d6cad5a52ea5': 742,
#  '468aa926-f032-47ac-8f10-e884f3eb4d43': 743,
#  '1af99f7e-06a7-4ba1-ba58-d49bc7a0539c': 744,
#  'b8a4d1cc-57f1-41a0-b990-94c400971a64': 745,
#  '39046fe5-3e15-40ef-9d49-72c5e1aaf5b1': 746,
#  '59bd28e7-2028-4335-968b-7a57594c10e2': 747,
#  '58a5ffa1-0d8e-4aa9-8404-f8172399b540': 748,
#  '7273bf88-9520-4337-b711-f8ca0cdbbf9e': 749,
#  'c588312f-1bc3-42e6-a2f2-0e330ac21a0b': 750,
#  '67a1ecc3-d298-4a9f-bfe0-2af0384c633a': 751,
#  '9656e1e7-4bd0-41e9-8f3d-8acf40fb8540': 752,
#  '718d57f3-bec8-4240-b7bf-ab3af9d948f4': 753,
#  '7f6389a0-cbda-4273-991e-be5602acddec': 754,
#  'b13c8f3d-64ac-4ecd-b6d6-5639985d405a': 755,
#  '7603898e-7696-475f-9239-c47296cd6975': 756,
#  '440eeb8e-8a66-4171-8c26-050696fd8423': 757,
#  'd4ff54f6-68ea-4821-b082-cb07b2ddf6b1': 758,
#  '57908670-d88b-40ee-bf0d-4b112cc0ef54': 759,
#  '1cf83766-a413-45cb-a855-a570b973c67e': 760,
#  'ecbbf70e-dd77-49bc-acb4-4c6a257eb249': 761,
#  '9fb26c00-3dca-4f39-9336-94af08c29669': 762,
#  'd6517894-a90b-49ea-84e4-53f110c9d536': 763,
#  '4f81b942-ac90-4acd-b69d-6bf3c347d8e8': 764,
#  'f2a71d2e-559a-452a-8ba1-631652732230': 765,
#  '1cbe0887-c379-4d66-8f52-d9cbf3dc70c9': 766,
#  'f7f46634-7dd0-4a88-947f-4a9e63b0786b': 767,
#  '7c6a4e2c-1d37-4c68-b6cb-e34c298b205d': 768,
#  '59592596-c161-439d-8e6c-ef206033dd02': 769,
#  'b2c5ceeb-f005-4c32-8c08-a9dd27fa8fbe': 770,
#  '02adc543-d19f-4358-a3c0-f1afbd1437ab': 771,
#  '1eccd618-619c-4873-a536-9a720a9ebe33': 772,
#  'f4b782b8-1d9e-4968-a88e-57797ee88ad8': 773,
#  '809f851b-2541-49de-a51c-df0b90d1e94b': 774,
#  '8b672f6c-b490-4cfc-b8c1-384316e6faf1': 775,
#  '29f554bb-f0df-4446-8903-b049175223fc': 776,
#  '80511868-3238-4e71-bc43-9b1229dd34c7': 777,
#  'f6f7be93-2f40-4f2d-96d3-117dbabdb770': 778,
#  '7e90ac73-18a1-4acf-a5a2-94605d05cc48': 779,
#  '8f5acacc-4dab-4eea-9109-163f9a423e8c': 780,
#  '98ee30c4-02ad-4dfc-a421-b3a1e904a945': 781,
#  'ac218505-f7af-4c9e-be00-46521de03d0f': 782,
#  '0594c428-4eff-4525-8d74-652b71a26ee6': 783,
#  '12373de6-0178-41b7-a8a9-c9f766231b22': 784,
#  '7908d41c-f813-4d1b-ab96-0eb50e9a1002': 785,
#  '736fcdcf-5bd2-441d-a86f-93107f603fc3': 786,
#  '5da41ca1-8276-44cd-b2c6-71964c8954da': 787,
#  'a612d518-579a-42c7-9997-be72904c7bd9': 788,
#  'c3475006-9012-4fde-ab7f-39f6d8569237': 789,
#  '74d63cfd-5473-4c31-a86f-fd823ad824f7': 790,
#  '443caeeb-4ab8-4b87-a500-0253aae73fb2': 791,
#  '2a68dbd2-7235-41c5-9c9d-9110a759e090': 792,
#  '21ad5ca1-88b1-49be-95c9-4bcddd70cce8': 793,
#  '6e33c64b-30c3-4143-95ea-4fc21bc4d497': 794,
#  'e7303e03-e6ac-4194-a6d9-623d0d9c0094': 795,
#  '9d4b5425-7641-4669-b996-c0fa8117f214': 796,
#  '05fd89eb-cb27-4704-9484-42b09b342c40': 797,
#  '6c291ea4-18b5-49b5-b9e7-d9066080cda8': 798,
#  '6a249a73-3b64-46ce-bea3-23ae1169a636': 799,
#  '2b980446-59bb-48bb-9bc9-ddcedfaa54c5': 800,
#  '74731b33-4ee9-444a-a473-4578c39a824d': 801,
#  'fd00b9c1-20bb-45a0-8899-acb61a20f92c': 802,
#  '080ce5f0-3aad-4ada-a99e-0d97bf5f5c9d': 803,
#  '5a150c8f-f359-4648-a17a-1f4093fc4422': 804,
#  '03c6678d-39b8-4c8a-bc14-971ee20857db': 805,
#  '2a1eecdb-4a93-49e8-973a-a788860de6fe': 806,
#  'b1a58071-d89e-4696-8ce7-0fdcd74294f6': 807,
#  '074bbfeb-3e22-4d93-ae34-293533562329': 808,
#  '2f9a1207-1e41-4a39-ad93-9f7945def832': 809,
#  'ac27144e-75fc-4185-b201-58202eb70ace': 810,
#  'f5f7c031-7ef2-427a-8dc9-3240e184d7c1': 811,
#  'ffb36d66-cf6e-4b5c-a9e5-b242132101be': 812,
#  '3a10832b-87bb-451b-b846-71195aef6fca': 813,
#  'c89f0c2a-41b7-4307-8c4a-ea1f04cfada7': 814,
#  '4df030f3-f62d-4737-9cea-0e10e4b7cf55': 815,
#  'dd6c3c5c-fd57-4d8c-8680-4cf87b60c404': 816,
#  '95eaa68f-b2bb-4ee5-a4b9-228cec9196f8': 817,
#  'f9fe1722-d14f-4896-8fa7-ee4d74eaa2f1': 818,
#  '3967eb5f-91a1-4221-979e-481a6aab62dd': 819,
#  '5fd24269-720d-4583-98c8-c6105674426b': 820,
#  '6047afd8-aec3-4f50-b98b-76e906aeea2a': 821,
#  'baa45b79-c195-4433-9bc8-3c3049e46399': 822,
#  '21e3fd46-b361-41b8-983d-5276dee035b1': 823,
#  '9c302866-4250-490d-aa48-5f6abbfc83a8': 824,
#  'd31b4dcc-d59c-4541-bd5f-add8a0bbabcf': 825,
#  'fd7d03bc-384b-452c-b1a1-faa8bd7de548': 826,
#  'f2171711-9936-4265-83b1-e702562437ae': 827,
#  '6ae191d5-1472-4614-9d49-0d6397689832': 828,
#  '4e4da728-f5c7-4e82-8cc4-be73bde55283': 829,
#  'e1fe4170-af57-4206-a4ee-687cb0cd5434': 830,
#  '6518d0c3-206a-4a37-bf17-e5c7ab9e64a1': 831,
#  '5a677ba1-d6b1-4981-b37f-a9552173fec0': 832,
#  'e051d67b-b86b-4883-a1ff-d24062a44c86': 833,
#  '85b13ce7-1758-4e0a-a2df-0afd9b50fc18': 834,
#  '4e5624df-b778-4022-a318-d0ee4beb583e': 835,
#  '16a20643-174c-41fc-b238-413b41b68500': 836,
#  '6cb0cd3c-19c2-4c71-b4db-740a26bd49ba': 837,
#  '5e601a4d-ff31-4950-becb-5e0f772184ec': 838,
#  '7a077f9e-9329-4aac-aed0-0ddc21cadb5b': 839,
#  '047c0139-3a1c-49f5-8b08-a4505c471f66': 840,
#  'a8647b55-93e5-4e24-9646-cad5ce64530d': 841,
#  'f312311f-3573-4631-9992-8003b605e502': 842,
#  'b6b551d5-6388-46dd-a6f5-e52593c0cdd8': 843,
#  '85f30664-1a52-4bbc-b120-63dc302e1f29': 844,
#  'f952cb46-31ee-49ff-a6a5-92254aa08663': 845,
#  'a4dda069-01b0-471f-b559-c75f84f77ab8': 846,
#  'f1622504-066d-431f-9ae0-4682877c18e0': 847,
#  '8f42e6d3-6bbf-4fa0-9e8a-b01c92c05e6f': 848,
#  'de550623-e48c-4d63-b02e-09c29a0b7533': 849,
#  'a2812556-e421-44ee-8de3-9ed89cbf0d9c': 850,
#  'd290b90d-3401-49a4-8b48-09113b2fd185': 851,
#  'a215f177-d408-4e77-b189-8ad311cf3b5e': 852,
#  '2de9b630-42b4-49eb-be5a-51d84256de3c': 853,
#  'af269ee4-4e13-4455-b2ad-4485a020aeee': 854,
#  '5394311a-8502-484a-a62c-36af3d05c221': 855,
#  'a05bd4a8-5507-479f-9fad-7578b4098908': 856,
#  '27c7997a-7256-4760-8d67-3c2f4fbb7d02': 857,
#  'bf94365a-0a97-4c21-8090-95c4e8744e96': 858,
#  'ffe852d4-8af2-425a-b191-bcdbb950b464': 859,
#  'c70c46cd-8d42-4dec-bc52-fd29628fb130': 860,
#  '6b284908-9f3b-4716-bce7-71cef8fa6eaa': 861,
#  '2814ec96-e4a2-4776-87dc-0d9766fe1973': 862,
#  '9e18091a-ea5a-4791-b1ca-ff98d376a7b7': 863,
#  '3468c34b-9f98-4078-9511-bd99f1c613e3': 864,
#  '5234e78d-cdf1-4414-8d6c-fd2ab8fa824a': 865,
#  '55402795-07b3-4de6-af04-646c9b49d4de': 866,
#  '4f3212ee-0d1b-47a7-a2a1-47d17c9ff412': 867,
#  '902df7f2-0be0-4be8-ae92-6a6ea71839ad': 868,
#  '5811cdfb-f1de-46ce-8ddb-473fc97a7c80': 869,
#  '913c3607-ca6f-4b21-ac37-b095dd38d25c': 870,
#  '06fa2564-c3ef-44c3-9151-24e97516d2de': 871,
#  'acbe5d17-50eb-49cb-a573-7dc363201781': 872,
#  '935fa853-f84c-4359-91b9-9097efc840cf': 873,
#  '9c5f5fc0-5f90-435e-a839-1ed77b46bb25': 874,
#  '96d0bec2-e8fa-4ab8-9228-137fbaba5640': 875,
#  '65c58487-a4a0-4db9-a911-fc8ef0e4d5a6': 876,
#  '6a9e1db5-e857-4d20-9e71-52bc1e768148': 877,
#  '02f2c514-dd26-4ac6-8d37-50c4437f603c': 878,
#  '09598e3e-5899-4235-b92d-707f55d9fd5a': 879,
#  '6801552b-a636-4791-972f-552bd4f15be5': 880,
#  '228f7301-0260-4545-8e17-c51a6d002d94': 881,
#  '6b4c7199-7576-4984-abcb-09d5fb6e5ecf': 882,
#  '7bff3d74-762f-458a-9870-d7b8c2295d49': 883,
#  '7585c7db-e68d-41c3-8419-d1138876cbaa': 884,
#  '905a2392-a370-4cb7-945b-288aca7d42b5': 885,
#  '3bd55994-51b1-4f2e-9ca3-058fd22b2439': 886,
#  '9caf30a3-02cc-4dcd-b7af-e7cd1ea66816': 887,
#  '91a92986-aa74-49f5-8670-70467e1f4e16': 888,
#  'b8bc5ba2-0b8d-4b23-9545-8ee4a522cd44': 889,
#  '374cf978-bc3f-4d20-b128-1b764de32a3f': 890,
#  '185b06f3-8deb-4f3a-bce7-285950d8e48d': 891,
#  'c915dea6-3fb7-44a2-9807-73372338feae': 892,
#  '9b6f29df-dff7-4d8f-9e6c-8e31bd2532c4': 893,
#  'ecc46359-17a3-496c-bf29-6e139267e355': 894,
#  '8fb8d9cd-ef96-413a-90ff-f1ad464fc98f': 895,
#  '420a5dae-adb5-4f3e-a834-2767cd427f3f': 896,
#  '703e8db0-c23d-4c94-a556-b91f125f09ea': 897,
#  '40acbd31-4b63-408c-86e5-e7260ca441b3': 898,
#  'f9db1498-a7ae-42e6-ad62-0037cd63d9c0': 899,
#  '9f8defe0-3834-4c2d-b05c-64719122a771': 900,
#  '8da85ea8-1893-41b8-b08e-86c4102d8ec3': 901,
#  'b01924ac-5bf4-4256-a98a-c76e6b9cea1d': 902,
#  '2f544ec9-7238-448a-bf36-12e128daddec': 903,
#  '2dfd9cb9-5d89-4ef3-a913-2b04fd024ec4': 904,
#  '8bdf8b60-0d96-46b3-bd1d-f9b4aa67fb65': 905,
#  '62e392ea-7b87-4543-ac47-50a4d37092d9': 906,
#  'e1bbb4b7-b4ff-4f68-8c96-984af1abca23': 907,
#  '08a8dfe8-9b10-46bb-a965-197772824862': 908,
#  'ca4e3f50-964d-4a93-abde-d2854d77b3c0': 909,
#  '21719b54-f1a8-496c-9e15-924b1619c2a9': 910,
#  '0d66f6c5-e3fb-400c-9c7c-072dbca07dde': 911,
#  '6bd6fc94-cb81-4438-bb46-5c9a16a65a73': 912,
#  'dbdc6902-3f22-4b1f-bda0-6347fd8ebaa4': 913,
#  '2966d567-58de-429f-b021-d2eaebd92fc5': 914,
#  '7fc3b8af-2e8a-42b5-ba9d-cbac82e1da84': 915,
#  '45f7320e-29bb-466f-ba2b-fc09c9bea72e': 916,
#  '7f74324f-381a-4fbc-ab91-7848c3f5a5a6': 917,
#  '29439eef-73e6-482b-95c4-15e68a0cd58f': 918,
#  '14d01eda-29fa-49b6-be93-57817311c2e8': 919,
#  '4b888e44-7250-4ae7-bf72-8baa9a916f45': 920,
#  '741bc499-93a9-4c73-a018-f4ac1b15e4d6': 921,
#  '5de75fe9-b07e-456b-837c-e4611c18bf81': 922,
#  '06478943-a1b4-4889-97c8-0bac5fac1f8f': 923,
#  'b9c35703-2394-479d-b03e-20a77554db59': 924,
#  'db5de970-29a7-4290-a80c-a01d756cfcbf': 925,
#  '18466dbc-c706-46b4-98c1-93ec88d255a2': 926,
#  '74bf58c0-d614-4ea8-a13a-f52c400c8b7e': 927,
#  'e76d1bb9-77e8-4d24-9401-1becbd34350b': 928,
#  'bbd2fd49-319b-47bc-b08d-bd963f668da1': 929,
#  '5ad99785-02eb-412b-85a7-2c067b8ea95f': 930,
#  '17a9ba89-da4f-4252-aa84-383ac283a5b3': 931,
#  '4682aa7e-ec12-4985-8649-699c0344462c': 932,
#  '42815c88-a50c-4512-b405-5c6c70134e3c': 933,
#  '85bd93ab-224f-4b52-bfcb-b7ad82a3eb9d': 934,
#  'a33e6a10-fe3b-43d8-a262-1ce10d19be19': 935,
#  '999d3cc8-ce66-47a7-b365-a976e80d8a14': 936,
#  'd3a5e10e-a824-4bc6-8014-f5480b56f0f9': 937,
#  '6e9251ec-75fa-4709-8474-10f5d3e2ed40': 938,
#  'd3c6c787-4cb7-4389-9f68-c3bd29543977': 939,
#  '5d78202b-31a6-4342-81be-b736ba507512': 940,
#  '608b527f-7e81-4a63-93dc-40c1078f4182': 941,
#  '4666b619-ddca-44e6-af70-39e68cbdd493': 942,
#  'd4bfa29c-e3c5-46c2-b643-4d6e70e9ac7d': 943,
#  'f8f9109e-29e7-4131-8759-a255a51a3781': 944,
#  '169232b9-1a42-4777-bfa4-a19bdd6db8ed': 945,
#  '3ae3e197-4b8f-4409-8c39-0e13c1b7c798': 946,
#  'eb92fabb-928d-4a66-923d-a95fb640f332': 947,
#  'e262df1b-ccfd-439a-a98b-f6972a881ba0': 948,
#  'da24473a-617b-4ff7-a59b-780b16b8a00e': 949,
#  'f4834d67-b778-46ed-9b3c-2ac59bc7ae85': 950,
#  'db389fa7-cc34-4ca8-a78d-834cd7dcff60': 951,
#  '052ee3fa-f7be-4d58-aae9-d5623d782173': 952,
#  '8ea7f0fe-8096-4033-9e01-34c43b58baa7': 953,
#  '457657ab-8c38-428a-974a-2fd31d8416c3': 954,
#  'f304df9c-808f-456d-a897-ab3075156c05': 955,
#  '4ee94d5f-059a-4a14-bcc8-73d831d00b2a': 956,
#  'da38a52b-abd4-4b5c-b8ed-61ac08be4b2e': 957,
#  '0e898d93-32e0-43b7-8237-8f233bc44ead': 958,
#  'c5f0659a-cffc-4099-93e7-afea61a27b15': 959,
#  '3fe2093b-7a67-44a5-a5f5-c49a923fa3f0': 960,
#  '9e837265-2b4f-48f6-8c0a-b04496e616c0': 961,
#  '01b56a45-7ae9-45eb-a455-595de0c283dc': 962,
#  'c7aebc8c-9587-49f7-b936-74b0b6ee62cc': 963,
#  'f42e074e-b2e0-4534-a2e1-ed2d1ed5594d': 964,
#  'e16a457c-9603-4015-9e7d-0adb7f621e14': 965,
#  'ca632f03-c07d-4d4d-842b-2f7824509e7e': 966,
#  '836f581d-aad9-480d-8af9-0bb7f2031500': 967,
#  '3ec4d3c5-e9af-4e42-88f2-c0226b1f8a0a': 968,
#  '57c2ecc0-20a2-4c0a-9ff1-e381f72c5742': 969,
#  '3b86927f-a347-4e96-a587-f11c8ab41430': 970,
#  'a7cb3aac-4254-4bff-9346-aa558a340d5a': 971,
#  '525c6e66-332c-4a52-9d8c-0900f2beae95': 972,
#  'f472e569-62f4-4dc7-a07a-433aad2e4e5f': 973,
#  '470db8d6-1d1d-4926-9367-b951a4d5117c': 974,
#  '77c24c6e-b811-47b4-892c-4adab0bca9f4': 975,
#  '64604482-4682-4215-9bd5-f5ef2659b0c6': 976,
#  '51aaeeec-f0c9-4107-85dc-cad681cdb464': 977,
#  'f3b9afa1-9be5-4bce-aa49-1c7e0abfbc3d': 978,
#  '26ea5181-4ba3-42de-bdbf-e76ee6246961': 979,
#  '52f21b13-28bf-4b44-9c32-390d84e5ffb6': 980,
#  '5250046e-0c32-43d0-a7e5-53138a0a60a0': 981,
#  'ac175651-220e-438f-9ced-c4f1bcf86c41': 982,
#  '3779f4bd-b874-4995-b71c-8751faa4f89e': 983,
#  '2c5fff54-0034-44e8-85c8-4574a5b0355a': 984,
#  'c4447bcc-52b5-4335-90ee-b1c7ecd51424': 985,
#  '411161b2-1daa-426b-a525-bd8be9476b9c': 986,
#  '8042c68c-4c8c-4642-86c1-d13a678f5e99': 987,
#  'a74ee884-86b1-4516-9f22-ae13e341e5c3': 988,
#  'f29cd8c4-cc48-4e1b-b37d-7a7100d3d4d5': 989,
#  '3bd58331-6dc4-40c8-90ea-1589327d1aab': 990,
#  '49b7b868-0ca3-4691-bc24-f34b31a7bf82': 991,
#  '3c21606d-3e08-483e-a9b4-0d28f5d75dc6': 992,
#  'aa4f34dc-b9ff-489b-becb-1acbf85a42ec': 993,
#  'cb72d035-329c-4cca-a6e7-525b0fd55526': 994,
#  'd624d50f-9535-43f2-bd0c-ba7831c2a0ea': 995,
#  '77547dcc-35e4-4670-b314-ace2904c383a': 996,
#  'c22a3328-e966-4218-a17c-fd2455b5b3d2': 997,
#  'd7ea3788-2bf2-4d72-9fd5-e15c5569fdf0': 998,
#  '3756fcb8-cc4a-4231-91ce-c336f63d4150': 999,
#  ...}
